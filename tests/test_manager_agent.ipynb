# %% [markdown]
# # Manager Agent E2E Test + RAGAS Evaluation

# %%
# 1. env & 라이브러리
from pathlib import Path
from dotenv import load_dotenv
import sys

ROOT = Path.cwd().parent  # 노트북은 tests/ 하위에 있다고 가정
sys.path.append(str(ROOT))

load_dotenv(ROOT / ".env")
print(f"ROOT - {ROOT}")
print("환경 변수 로드 완료")

from services.orchestrator import router_node
from ragas import EvaluationDataset, SingleTurnSample, evaluate
from ragas.metrics import answer_relevancy, faithfulness, LLMContextPrecisionWithoutReference
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
# Out:
# ROOT - c:\Users\insung\Finance_Agent
# 환경 변수 로드 완료
# 2025-08-04 13:00:18,493 | INFO | Loading faiss with AVX2 support.
# 2025-08-04 13:00:18,538 | INFO | Successfully loaded faiss with AVX2 support.
# 2025-08-04 13:00:18,551 | INFO | Failed to load GPU Faiss: name 'GpuIndexIVFFlat' is not defined. Will not load constructor refs for GPU indexes. This is only an error if you're trying to use GPU Faiss.

# %%
# 2. Graph 호출 → Samples 변환

# 인덱스 준비되어 있다고 전제
SAMPLE_QUESTIONS = [
    # FAQ 타입
    "OTP 비밀번호 오류 해제 방법 알려줘",
    "해외에서 인터넷뱅킹 이용 시 주의할 점은?",
    # 상품 설명
    "우리 SUPER주거래 적금 3년 만기 금리가 얼마야?",
    "정기적금 우대이율 조건 요약해줘",
    # 가입/추천
    "나에게 맞는 적금 상품 추천해줘",
    "청년이라면 어떤 예금이 유리할까?"
]


samples = []
for q in SAMPLE_QUESTIONS:
    res = router_node.invoke(q)
    ctxs = res.get("context", "").split("\n\n")
    samples.append(
        SingleTurnSample(
            user_input         = q,
            response           = res["answer"],
            retrieved_contexts = ctxs,
        )
    )
dataset = EvaluationDataset(samples=samples)
# Out:
# 2025-08-04 13:00:25,868 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:26,851 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:29,001 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:29,725 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:30,533 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:34,164 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:35,210 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:35,552 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:36,229 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:37,349 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:38,047 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:38,866 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:39,430 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:40,362 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:41,402 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:41,967 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:42,551 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:42,784 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:43,656 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:47,149 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:51,107 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:52,026 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:52,355 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:53,251 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:00:53,662 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:00:56,988 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:01:00,153 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
import pprint
pprint.pp(samples)
# Out:
# [SingleTurnSample(user_input='OTP 비밀번호 오류 해제 방법 알려줘', retrieved_contexts=['Q: 보안카드(OTP발생기) 비밀번호 오입력횟수가 초과되었어요. 인터넷뱅킹에서 오류해제 가능한가요?\nA: 보안카드 비밀번호 연속 3회 또는 OTP발생기 비밀번호 연속 10회 오입력 초과 시 보안매체를 이용할 수 없습니다. 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 가능합니다. (인터넷뱅킹에서는 불가)', 'Q: 이용자비밀번호 3회 오류 상태인데, 인터넷뱅킹에서 오류 해제 할 수 있나요?\nA: 기존 이용자비밀번호를 알고 있다면 인터넷뱅킹에서 오류해제 할 수 있습니다. (보안매체 및 인증서 입력 필요)', '▶ 인터넷뱅킹 경로 안내 : 개인뱅킹 로그인→ (아이디 로그인 영역) 비밀번호 재등록→ 이용자비밀번호 3회 오류해제', '※ 이용자비밀번호 3회오류인 경우, 아이디로그인은 불가하나 인증서 등 다른 방법의 로그인은 가능합니다.(법인 제외)', '※ 인터넷뱅킹에서 오류해제가 불가하다면, 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 및 비밀번호 재등록을 할 수 있습니다.', 'Q: 이용자비밀번호(로그인비밀번호) 2회 오류 상태인데, 인터넷뱅킹에서 재등록 할 수 있나요?\nA: 인터넷뱅킹에서 이용자비밀번호 재등록이 가능하며, 보안매체와 인증서 입력이 필요합니다.', '', '▶ 이용자비밀번호 재등록 경로 안내 : 개인인터넷뱅킹 → (아이디 로그인 영역) 비밀번호재등록 → 이용자비밀번호 재등록', '', '※ 인터넷뱅킹에서 재등록 불가하다면, 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 및 비밀번호 재등록을 할 수 있습니다.'], reference_contexts=None, response='OTP 비밀번호 오류 해제 방법은 다음과 같습니다:\n\n1. 우리WON뱅킹에 접속합니다.\n2. 비대면 실명확인 절차를 진행합니다.\n3. 오류가 해제된 후, 필요한 경우 비밀번호를 재등록합니다.\n\n※ 인터넷뱅킹에서는 OTP 비밀번호 오류 해제가 불가능합니다(①).', multi_responses=None, reference=None, rubrics=None),
#  SingleTurnSample(user_input='해외에서 인터넷뱅킹 이용 시 주의할 점은?', retrieved_contexts=['Q: 해외에서 인터넷/스마트뱅킹을 이용하려면 출국하기 전에 확인할 사항이 있나요?\nA: 해외 출국 전 아래 사항을 확인 바랍니다.\n1) 해외IP차단서비스 해제 (필수)', '2) 단말기지정서비스 해제 또는 미지정기기 옵션 허용 권장', '3) OTP발생기(디지털OTP) 사용자는 보안카드 지참 권장', '- 고장, 분실 등 비상시 보안매체를 보안카드로 변경 가능(단, 전자뱅킹 이체한도 하향될 수 있음)', '4) 금융인증서/우리WON인증서 사용자는 공동인증서 추가 발급 권장', '5) 비밀번호 오류상태 사전 체크', '6) 전자뱅킹 이체한도 및 이용하려는 계좌 상태(한도제한 등) 확인', '7) 은행에 등록된 고객정보(성명, 연락처 등) 정비', '', '※ 국내통신망이 아닌 경우 이용이 불가할 수 있으며, 국내통신망을 이용하더라도 현지 통신망 상황에 따라 일부 제한될 수 있습니다.', 'Q: 이용자비밀번호 3회 오류 상태인데, 인터넷뱅킹에서 오류 해제 할 수 있나요?\nA: 기존 이용자비밀번호를 알고 있다면 인터넷뱅킹에서 오류해제 할 수 있습니다. (보안매체 및 인증서 입력 필요)', '▶ 인터넷뱅킹 경로 안내 : 개인뱅킹 로그인→ (아이디 로그인 영역) 비밀번호 재등록→ 이용자비밀번호 3회 오류해제', '※ 이용자비밀번호 3회오류인 경우, 아이디로그인은 불가하나 인증서 등 다른 방법의 로그인은 가능합니다.(법인 제외)', '※ 인터넷뱅킹에서 오류해제가 불가하다면, 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 및 비밀번호 재등록을 할 수 있습니다.', 'Q: 인터넷뱅킹을 오랫동안 이용하지 않아서 자금이체가 제한되었다고 나와요. 인터넷뱅킹에서 해제 하는 방법이 있나요?\nA: 12개월이상 인터넷/스마트뱅킹을 통한 로그인 등 이용이 없는 경우 장기미사용으로 자금이체 거래가 제한됩니다. 인터넷뱅킹에서 자금이체 거래제한을 해제 할 수 있으며. 보안매체 및 인증서 입력이 필요합니다.', '▶ 자금이체제한/해제 경로 안내 : 개인인터넷뱅킹 → 뱅킹관리 → 인터넷뱅킹관리 → 자금이체제한/해제', '※ 우리WON뱅킹에서도 자금이체제한해제 가능합니다.'], reference_contexts=None, response='해외에서 인터넷뱅킹을 이용할 때 주의할 점은 다음과 같습니다.\n\n1. 해외IP차단서비스 해제 (필수)\n2. 단말기지정서비스 해제 또는 미지정기기 옵션 허용 권장\n3. OTP발생기(디지털OTP) 사용자는 보안카드 지참 권장 (고장, 분실 시 보안매체를 보안카드로 변경 가능, 단 이체한도 하향 가능)\n4. 금융인증서/우리WON인증서 사용자는 공동인증서 추가 발급 권장\n5. 비밀번호 오류상태 사전 체크\n6. 전자뱅킹 이체한도 및 이용하려는 계좌 상태(한도제한 등) 확인\n7. 은행에 등록된 고객정보(성명, 연락처 등) 정비\n\n※ 국내통신망이 아닌 경우 이용이 불가할 수 있으며, 현지 통신망 상황에 따라 일부 제한될 수 있습니다. (①)', multi_responses=None, reference=None, rubrics=None),
#  SingleTurnSample(user_input='우리 SUPER주거래 적금 3년 만기 금리가 얼마야?', retrieved_contexts=['Q: 현재 거주하고 있는 전세주택의 임대차계약으로도 전세대출이 가능한가요?\nA: 거주중인 전세주택의 경우는 거주기간, 보증금 증액 여부 등 자금의 용도에 따라 가능 할 수 있습니다.', '단, 상품의 대출 대상자요건, 주택요건, 소득 및 부채 등의 요건에 따라 달라질 수 있으므로 자세한 대출상품 내용은 홈페이지를 참고하여 주시기 바랍니다.', '', '▶ 전세자금대출 신청시기', '① 주택도시기금 전세자금대출', '- 신규자금 : 임대차계약서상 잔금지급일과 주민등록등본상 전입일 중 빠른날로부터 3개월 이내', '- 계약갱신 : 전입일로부터 1년 이상 경과하고, 계약갱신일로부터 3개월 이내(보증금 증액이 있는 경우만 가능)', '(단, 공공임대는 전입일로부터 3개월 이상 경과하고, 계약갱신일로부터 3개월 이내로 보증금이 증액된 경우 가능)', '② 은행 전세자금대출', '- 신규자금 : 임대차계약서상 잔금지급일과 주민등록등본상 전입일 중 빠른날로부터 3개월 이내', '- 계약갱신 : 전입일로부터 3개월 이상 경과하고, 계약갱신일로부터 3개월 이내(보증금 증액이 없는 경우에도 가능)', 'Q: 인터넷뱅킹을 오랫동안 이용하지 않아서 자금이체가 제한되었다고 나와요. 인터넷뱅킹에서 해제 하는 방법이 있나요?\nA: 12개월이상 인터넷/스마트뱅킹을 통한 로그인 등 이용이 없는 경우 장기미사용으로 자금이체 거래가 제한됩니다. 인터넷뱅킹에서 자금이체 거래제한을 해제 할 수 있으며. 보안매체 및 인증서 입력이 필요합니다.', '▶ 자금이체제한/해제 경로 안내 : 개인인터넷뱅킹 → 뱅킹관리 → 인터넷뱅킹관리 → 자금이체제한/해제', '※ 우리WON뱅킹에서도 자금이체제한해제 가능합니다.', 'Q: 연금저축펀드가 무엇인가요?\nA: 소득세법에 따라 도입된 제도로 일정 기간 입금 후 연금형태로 찾을 경우 연금소득으로 과세하는', '세제 혜택 금융상품이에요. 최소 5년이상 가입하고, 10년이상 연금을 지급받을 수 있어요.', '입금하는 기간 동안에는 연간 600만원 한도 내에서 세액공제가 가능해요.', '및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품', '달라질 수 있습니다.\n⋅만기 전 해지할 경우 약정한 이율보다 낮은 중도해지이율이 적용됩니다.\n⋅우대금리는 만기 해지 시에만 적용되며, 중도해지하는 경우 적용되지 않습니다.\n⋅’19.7.19.부터 “위비SUPER주거래적금Ⅱ”에서 “우리 SUPER주거래 적금”으로 변경되었습니다.\n  기존에 “위비SUPER주거래적금Ⅱ”를 가입한 고객님께서도 상품명이 “우리 SUPER주거래 적금”  \n  으로 변경되며, 우대이율은 시행일 이후 가입자에 대해서 변경된 상품 내용을 \n  적용받게 됩니다.\n⋅금리변동형 정기적금은 금리상승기에 약정금리 인상 가능성이 큰 반면, 금리 하락기에는 \n   약정금리 인하로 소비자에게 불리할 수 있습니다.', '보통위험\n 우리 일임형 고배당30 ISA(위험중립형)\n투자에는 그에 상응하는 투자위험이 있음을 충분히 인지하고, 예‧적금보다 높은 수\n익을 기대할 수 있다면 일정 수준의 위험을 감수할 수 있는 투자자에게 적합한 상\n품입니다.\n 우리 일임형 글로벌30 ISA(위험중립형)\n 우리 일임형 공모주알파 ISA(위험중립형)\n낮은위험\n 우리 일임형 회사채 ISA(안정추구형)\n투자원금의 손실위험은 최소화하고, 이자소득이나 배당소득 수준의 안정적인 투자를 \n목표로 하는 투자자에게 적합한 상품입니다.\n 우리 일임형 국공채 ISA(안정추구형)\n 우리 일임형 우량채 ISA(안정추구형)\n매우낮은위험\n 우리 일임형 안정형 ISA(안정형)\n예금 또는 적금 수준의 수익률을 기대하며, 투자원금에 손실이 발생하는 것을 원하지'], reference_contexts=None, response='해당 내용은 담당 직원 확인 후 안내하겠습니다(②). 추가적인 정보가 필요하시면 언제든지 문의해 주세요.', multi_responses=None, reference=None, rubrics=None),
#  SingleTurnSample(user_input='정기적금 우대이율 조건 요약해줘', retrieved_contexts=['Q: 가족이 방문하여 정기예금 만기해지를 대신 할 수 있나요?\nA: 예금해지는 본인이 방문하여 본인의사 확인 후 해지가 원칙입니다.', '다만, 부득이한 경우 적법한 위임관계가 확인되면대리인에 의한 해지가 가능할 수 있으므로방문하실 영업점으로 상담받아 보시기 바랍니다.', 'Q: 비과세종합저축 가입자격과 가입한도가 궁금해요.\nA: 전 금융기관을 통하여 5천만원 범위 내의 저축에서 발생하는 이자와 배당소득에 대하여 저축상품의 가입기간 관계없이 만기일 까지', '비과세 혜택을 부여하는 제도입니다.', '', '[가입자격]', '① 만 65세 이상인 거주자', '② 「장애인복지법」제 32조에 따라 등록한 장애인', '③ 「독립유공자 예우에 관한 법률」제 6조에 따라 등록한 독립유공자와 그 유족 또는 가족', '④ 「국가유공자 등 예우 및 지원에 관한 법률」제 6조에 따라 등록한 상이자', '⑤ 「국민기초생활보장법」제 2조 제 2호에 따른 수급자', '⑥ 「고엽제후유의증 환자지원 등에 관한 법률」제 2조 제3호에 따른 고엽제후유의증환자', '⑦ 「5·18 민주유공자 예우에 관한 법률」제 4조 제2호에 따른 5.18민주화운동 부상자', '[가입한도]', '- 1인당 원금을 합하여 5천만원 이내', '- 기 가입한 세금우대저축, 생계형저축한도를 포함한 통합한도', '- 가입한도내 다수 계좌 개설 가능', '[가입시한]', '- 2025년 12월 31까지 가입 가능합니다.', '- 2020년 1월 1일 이후 비과세종합저축 가입자는 소득요건을 충족하지 못할 경우 불이익을 받을 수 있음', '- 소득요건 추가 : 직전 3개 과세기간 內 1회 이상 금융소득종합과세 대상자는 제외', '(종합소득 종합과세 대상자는 금융소득 연간 합계액이 2천만원을 초과하는 경우임)', 'Q: 인터넷뱅킹에서 정기예금, 적금을 담보로 대출이 가능한가요?\nA: 네, 가능합니다.', '▶ 가능금액 : 예·적금 잔액의 95%이내 (단, 10만원 단위로 가능합니다.)', '▶ 적용금리 : 예·적금 수신금리 + 1.0%', '▶ 인터넷뱅킹 경로 :대출 → 인터넷대출신청 → 예금담보대출 → 대출신청', '※ 유의사항', '①예·적금 가입일 포함 3영업일째부터 가능합니다.', '②일부상품은 담보대출이 불가할 수 있습니다.', '③인터넷뱅킹에서 예적금담보대출의 최고한도는 1억원까지 가능합니다.'], reference_contexts=None, response='추가 확인 필요. <context>에는 정기적금 우대이율 조건에 대한 정보가 포함되어 있지 않습니다.', multi_responses=None, reference=None, rubrics=None),
#  SingleTurnSample(user_input='나에게 맞는 적금 상품 추천해줘', retrieved_contexts=['Q: 어떤 펀드가 전문가 포트폴리오에 추천되나요?\nA: 우리은행에서 자체개발한 투자상품 평가모델(WISE)을 활용, 정량적 평가(우량 상품 선별)와 정성적 평가(경제 및 시장 전망)을 합쳐 포트폴리오 우선 편입 상품을 결정하여 추천드립니다', 'Q: 나의 투자성향 등급 상품만 가입가능한가요?\nA: 투자성향 등급상품만 가입 가능한건 아니에요.', '내 성향 이하(예: 위험중립형인 경우, 안정형과 안정추구형도 신규가능)의 추천 포트폴리오도 선택가능합니다.', 'Q: 연금저축펀드 가입 및 해지시 어떤부분을 유의해야할까요?\nA: 연금저축펀드 운용 중 연금수령방법이 아닌 연금 외 수령방법으로 일부 또는 전부해지를 할 경우', '세액공제 받은 금액과 운용수익에 대해 기타소득세 16.5%가 부과돼요. 따라서 장기적으로 운용해야  하는 상품이니 투자자의 자산 및 소득 등 재정 상태를 고려하여 가입하는 것이 좋아요.', '부득이 일부 또는 전부해지를 할 경우 세액공제 받은 금액을 확인하여, 세액공제를 안받았거나', '입금액보다 적게 세액공제를 받았으면 과세제외 요청을 별도 신청하셔야 해요.', '및 특징\n⋅상 품 명 : 「우리 퍼스트 적금2」\n⋅상품특징 : 우리은행 신규 고객님과 직전 6개월동안 예·적금을 미보유한 고객님께\n우대금리를 제공하는 적립식 상품', '있습니다.\n   ※ 본 서류는 법령 및 내부통제기준에 따른 절차를 걸쳐 금융소비자에게 제공되는 문서입니다.\n 이 상품은 우리은행 개인금융솔루션부에서 개발한 상품입니다. 본 상품에 대한 문의사항 또는 민원 \n상담이 필요하시면 영업점, 우리은행 고객센터(1588-5000), 우리은행 홈페이지(www.wooribank.com)를 \n통해 문의주시기 바랍니다. 또한 본 상품에 대하여 당 은행과 분쟁이 있는 경우에는 금융소비자보호법에 \n따라 금융감독원 민원상담 센터(국번없이 1332) 또는 e-금융민원센터(https://www.fcsc.kr)에 분쟁조정을 \n신청할 수 있습니다.\n<부록> 예금상품 설명을 위한 관련 용어 안내\n용어\n설명\n압류\n▪ 채무자의 특정한 재산에 대하여 처분(매매, 양도 등)을 금지하게', '및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품', '및 특징\n⋅상 품 명 : 「우리 Magic 적금 by 롯데카드」\n⋅상품특징 : 우리은행과 롯데카드 거래실적에 따른 우대금리를 제공하는 상품', '’22.1.1 ~ ’22.12.31\n(납입원금+은행이자+1%이자지원금) X 33%\n’23.1.1 ~ ’23.12.31\n(납입원금+은행이자+1%이자지원금) X 71%\n’24.1.1 이후\n납입원금 X 100%\n<별지> 「우리 장병내일준비적금」연계·제휴서비스\n구  분\n내   용\n비 고\n연계/제휴\n서비스 내용 \n(무료상해보험)\n • 제공기준 : 적금 신규 시점주1)에 아래 ①,② 조건을 모두 \n   충족하는 경우 \n   ① 우리은행 통장에서 이 적금으로 자동이체 등록\n   ② 우리은행 주택청약종합저축 상품 가입 고객 \n  ※ 주1) 이 상품의 신규월\n • 무료상해보험(DB손해보험 제공) 가입 서비스 \n  - 보장기간 : 적금 신규가입 다음 월 15일부터 21개월 동안 제공', '예금자보호\nX\n‣ 주택도시기금의 조성재원으로 정부가 관리\n ‣ 유의사항\n ※ 상품 관련 특약 및 상품설명서를 확인하신 후, 상품 가입 전 궁금하신 사항은 \n   반드시 우리은행 영업점 혹은 고객센터(☎1588-5000)로 문의하시기 바랍니다.'], reference_contexts=None, response='고객님의 상황에 따라 적합한 적금 상품을 추천해드리겠습니다.\n\n1. **우리 퍼스트 적금2**: 신규 고객님이나 직전 6개월 동안 예·적금을 미보유한 고객님께 우대금리를 제공하는 적립식 상품입니다. 이러한 조건에 해당하신다면 이 상품이 적합할 수 있습니다.\n\n2. **우리 SUPER주거래 적금**: 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품입니다. 이미 우리은행에서 거래를 하고 계신다면 이 상품이 좋을 수 있습니다.\n\n3. **우리 Magic 적금 by 롯데카드**: 우리은행과 롯데카드 거래실적에 따른 우대금리를 제공하는 상품입니다. 롯데카드를 사용하고 계신다면 이 상품도 고려해볼 수 있습니다.\n\n고객님의 구체적인 상황이나 필요에 따라 더 자세한 상담이 필요하시면 우리은행 영업점이나 고객센터(1588-5000)로 문의하시기 바랍니다.\n\n---\n아직 가입 상담 기능은 PoC 단계입니다.\n예금/적금 기본 정보를 먼저 확인해 봐주세요!', multi_responses=None, reference=None, rubrics=None),
#  SingleTurnSample(user_input='청년이라면 어떤 예금이 유리할까?', retrieved_contexts=['Q: 미성년자 본인 예금가입 시 부모님과 함께 가야하나요?\nA: 만 14세 이상 미성년자는 본인만 방문하여도 예금 가입이 가능합니다.', '다만, 입출금이 자유로운 계좌 개설 요청시 대포통장 발생 방지를 위한 금융거래목적확인 증빙서류를 필수제출 해야합니다.', '증빙서류 미 제출시, 계좌 개설이 제한되거나 추가 보완서류를 요청할 수 있습니다.', '※ 만 14세 미만의 미성년자는 단독으로 방문하여 계좌 개설불가하므로 법정대리인에 의한 계좌 개설만 가능', '※ 미성년자 명의의 예금은 제신고, 해지 시 친권자 전원의 동의가 필수입니다.', 'Q: 인터넷뱅킹에서 정기예금, 적금을 담보로 대출이 가능한가요?\nA: 네, 가능합니다.', '▶ 가능금액 : 예·적금 잔액의 95%이내 (단, 10만원 단위로 가능합니다.)', '▶ 적용금리 : 예·적금 수신금리 + 1.0%', '▶ 인터넷뱅킹 경로 :대출 → 인터넷대출신청 → 예금담보대출 → 대출신청', '※ 유의사항', '①예·적금 가입일 포함 3영업일째부터 가능합니다.', '②일부상품은 담보대출이 불가할 수 있습니다.', '③인터넷뱅킹에서 예적금담보대출의 최고한도는 1억원까지 가능합니다.', 'Q: 영업점 창구에서 송금하면 수수료는 얼마인가요?\nA: 우리은행 계좌로 창구 송금 수수료는 면제입니다.', '[다른은행 계좌로 창구 송금 수수료]', '- 10만원 이하 600원', '- 10만원 초과 2,000원', '- 100만원 초과 3,000원', '※ 1회 5억원 까지 송금 가능하고, 1일 한도는 제한없습니다.', '• 회차별 최소 1천원 이상 1천원 단위로, 매월(월 초일부터 말일까지) 70만원 이하\n  ※ 만기일 전일까지 자유롭게 저축 가능, 연간 납입한도 840만원\n구 분\n내 용\n청년희망적금\n만기지급금\n일시납\n• 청년희망적금 만기해지 고객은 청년희망적금 만기지급금 \n  (원금+이자+저축장려금)이내에서 청년도약계좌 가입 시 일시납 가능\n• 최소 200만원 이상 청년희망적금 만기지급금 이하 금액에서 일시납 금액\n  (월 40/50/60/70만원 중 선택), 일시납입 기간 선택 후 일시납 확정\n• 일시납은 청년희망적금 만기일이 속하는 달의 다음 달 말일까지\n  청년도약계좌에 가입신청하는 경우에만 가능\n   ※ (예시) ’24년 2월 만기고객의 경우, ‘24년 3월까지 가입신청 진행필요', '▷ 어린이 전용 적금상품으로 자유롭게 적립 가능한 적금\n기본금리\n(세금납부 전)\n’25.06.20. 기준\n ▷ 아래의 이율은 2025.06.20. 세금납부 전 기준 이율이며 신규 당시의 \n    이율은 실제로 통장에 인자된 이율이 적용됩니다.\n    (인터넷 가입 시는 가입화면에서 확인)\n    \n계약기간\n기본금리(%)\n최고금리(%)\n12개월\n 연 2.45%\n연 3.65%\n우대이율\n(세금납부전)\n ▷ 적금 계약기간 중 지문등록 후 [아동등 사전신고증]을 계약기간의 \n    만기일 전일까지 제출하는 경우 : 연 1.0%p\n   ※ 지문등록 대상과 가입자 일치 필요\n    ※ [아동 등 사전신고증]은 경찰서 방문 또는 안전Dream 홈페이지에서 발급 가능', '금액을 10원 단위로 자유롭게 납입\n・ 단, 입금하려는 금액과 납입누계액의 합이 1,500만원 이하인 경우 100만원을 초과하\n여 입금 가능\n□ 전환신규한 경우 전환원금이 1,500만원 이상인 경우에는 다음 회차부터는 매월 100\n만원을 초과하여 입금 불가\n납입기간\n□ 가입일로부터 해지일까지(*입주자로 선정된 후에도 납입 가능)\n적용이율\n□ 가입일로부터 2년 이상인 경우, 다음에 해당하는 납입원금과 무주택기간에 대하여 \n   「청년 주택드림 청약통장」이율을 적용\n・ 단, 청약당첨으로 인한 해지인 경우에는 가입기간 1개월 초과 2년 미만이라도 「청년\n   주택드림 청약통장」이율을 적용\n□ 납입원금: 5,000만원 한도 내\n・ 전환신규한 계좌의 경우, 전환신규 후 추가 입금분부터 「청년 주택드림', '일반적으로 담보물이 동산 또는 권리(예·적금, 채권 등)인 경우에 \n활용됩니다.\n출연\n▪ 어떤 사람이나 단체가 자기의 의사에 따라 돈을 내거나 의무를 \n부담함으로써 재산상의 손실을 입고 남의 재산을 증가시키는 일을 \n말합니다. \n▪ 일반적으로 기부행위를 일컫는 말로 사용되나 법률적으로는 \n비영리재단법인에 재산을 무상으로 내는 행위를 뜻합니다.', '활용됩니다.\n출연\n▪ 어떤 사람이나 단체가 자기의 의사에 따라 돈을 내거나 의무를   \n 부담함으로써 재산상의 손실을 입고 남의 재산을 증가시키는     \n 일을 말합니다. \n▪ 일반적으로 기부행위를 일컫는 말로 사용되나 법률적으로는      \n 비영리재단법인에 재산을 무상으로 내는 행위를 뜻합니다.\n경과기간\n▪ (해당 시간을) 완전히 지나간 기간\n   * (예시) 입금일부터 해지일까지 지나간 기간', '활용됩니다.\n출연\n▪ 어떤 사람이나 단체가 자기의 의사에 따라 돈을 내거나 의무를   \n 부담함으로써 재산상의 손실을 입고 남의 재산을 증가시키는     \n 일을 말합니다. \n▪ 일반적으로 기부행위를 일컫는 말로 사용되나 법률적으로는      \n 비영리재단법인에 재산을 무상으로 내는 행위를 뜻합니다.\n경과기간\n▪ (해당 시간을) 완전히 지나간 기간\n * (예시) 입금일부터 해지일까지 지나간 기간'], reference_contexts=None, response="청년에게 유리한 예금 상품으로는 '청년희망적금'과 '청년 주택드림 청약통장'이 있습니다. \n\n- **청년희망적금**: 매월 1천원 이상 70만원 이하로 자유롭게 저축할 수 있으며, 연간 납입한도는 840만원입니다. 만기해지 후에는 청년도약계좌에 가입하여 일시납도 가능합니다.\n  \n- **청년 주택드림 청약통장**: 납입금액이 5,000만원 한도 내에서 자유롭게 납입할 수 있으며, 무주택 기간에 따라 이율이 적용됩니다.\n\n따라서, 자신의 상황에 맞춰 청년희망적금이나 청년 주택드림 청약통장을 선택하는 것이 유리할 것입니다. 가입을 고려해보세요!\n\n---\n아직 가입 상담 기능은 PoC 단계입니다.\n예금/적금 기본 정보를 먼저 확인해 봐주세요!", multi_responses=None, reference=None, rubrics=None)]

# %%
# 평가 설정
eval_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o-mini", temperature=0))
eval_emb = LangchainEmbeddingsWrapper(OpenAIEmbeddings(model="text-embedding-3-small"))

metrics = [
    answer_relevancy,
    faithfulness,
    LLMContextPrecisionWithoutReference(llm=eval_llm),
]

# %%
# RAGAS 실행
report = evaluate(
    dataset,
    metrics   = metrics,
    llm       = eval_llm,
    embeddings= eval_emb,
    batch_size= 4,
    show_progress=True,
)
df = report.to_pandas()
df.head()
# Out:
# Evaluating:   0%|          | 0/18 [00:00<?, ?it/s]
# Batch 1/5:   0%|          | 0/4 [00:00<?, ?it/s]
# 2025-08-04 13:04:09,847 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:09,932 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:09,966 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:10,058 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:10,103 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:11,690 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:12,016 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:12,178 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:12,184 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:12,186 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:12,189 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:12,651 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:13,176 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:14,739 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:16,091 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:17,536 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:18,866 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:19,240 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:20,739 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:22,307 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:23,356 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:24,854 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:25,791 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:25,849 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:25,952 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:26,311 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:26,652 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:26,815 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:26,819 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:28,352 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:29,215 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:29,367 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:29,495 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:31,104 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:32,264 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:33,707 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:34,416 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:35,865 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:37,446 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:38,523 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:39,820 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:39,973 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:41,108 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:42,216 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:43,381 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:44,545 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:46,155 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:47,821 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:48,684 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:48,753 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:48,830 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:49,201 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:51,052 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:04:51,195 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:51,200 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:51,203 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:52,502 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:52,976 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:53,388 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:53,715 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:54,514 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:55,029 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:55,541 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:56,320 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:56,653 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:57,615 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:57,703 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:58,897 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:04:59,043 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:00,245 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:00,272 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:01,393 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:01,405 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:02,509 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:02,863 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:03,634 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:04,672 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:04,846 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:05,958 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:06,035 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:07,088 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:08,233 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:08,430 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:09,478 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:09,826 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:10,653 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:11,350 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:11,801 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:12,895 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:13,017 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:14,176 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:14,529 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:15,263 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:16,412 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:16,424 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:17,871 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:18,467 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:19,456 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:19,848 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:20,874 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:22,212 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:24,573 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:25,685 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:26,733 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:28,035 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:29,115 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:29,169 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:29,436 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:29,566 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:29,611 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:30,006 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:05:30,371 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:05:30,530 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:30,892 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:31,729 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:32,091 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:05:32,533 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-08-04 13:05:32,838 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:32,842 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:34,256 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:35,590 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:37,094 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:38,362 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:39,654 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:41,356 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:42,783 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:44,099 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:45,344 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:46,056 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:46,843 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:48,107 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:49,471 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:50,852 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:50,870 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:52,164 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:53,436 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:55,436 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:56,874 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:58,170 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:05:59,479 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:01,206 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:02,469 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:02,791 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:03,969 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:06,334 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:07,574 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:09,042 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:10,367 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:11,849 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:13,294 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:14,434 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:16,210 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:18,031 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:21,903 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:23,146 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:24,648 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-08-04 13:06:26,234 | INFO | HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
#                       user_input  \
# 0          OTP 비밀번호 오류 해제 방법 알려줘
# 1        해외에서 인터넷뱅킹 이용 시 주의할 점은?
# 2  우리 SUPER주거래 적금 3년 만기 금리가 얼마야?
# 3              정기적금 우대이율 조건 요약해줘
# 4              나에게 맞는 적금 상품 추천해줘
#
#                                   retrieved_contexts  \
# 0  [Q: 보안카드(OTP발생기) 비밀번호 오입력횟수가 초과되었어요. 인터넷뱅킹에서 오...
# 1  [Q: 해외에서 인터넷/스마트뱅킹을 이용하려면 출국하기 전에 확인할 사항이 있나요?...
# 2  [Q: 현재 거주하고 있는 전세주택의 임대차계약으로도 전세대출이 가능한가요?\nA:...
# 3  [Q: 가족이 방문하여 정기예금 만기해지를 대신 할 수 있나요?\nA: 예금해지는 ...
# 4  [Q: 어떤 펀드가 전문가 포트폴리오에 추천되나요?\nA: 우리은행에서 자체개발한 ...
#
#                                             response  answer_relevancy  \
# 0  OTP 비밀번호 오류 해제 방법은 다음과 같습니다:\n\n1. 우리WON뱅킹에 접속...          0.696997
# 1  해외에서 인터넷뱅킹을 이용할 때 주의할 점은 다음과 같습니다.\n\n1. 해외IP차...          0.533919
# 2  해당 내용은 담당 직원 확인 후 안내하겠습니다(②). 추가적인 정보가 필요하시면 언...          0.000000
# 3  추가 확인 필요. <context>에는 정기적금 우대이율 조건에 대한 정보가 포함되...          0.000000
# 4  고객님의 상황에 따라 적합한 적금 상품을 추천해드리겠습니다.\n\n1. **우리 퍼...          0.000000
#
#    faithfulness  llm_context_precision_without_reference
# 0           0.8                                 0.666667
# 1           1.0                                 0.840476
# 2           0.0                                 0.000000
# 3           0.0                                 0.190794
# 4           0.8                                 0.601951

# %% [markdown]
# ## Overall Scores

# %%
df_overall = df[[
    "answer_relevancy",
    "faithfulness",
    "llm_context_precision_without_reference"
]].mean()

print(df_overall)
# Out:
# answer_relevancy                           0.283656
# faithfulness                               0.550000
# llm_context_precision_without_reference    0.395057
# dtype: float64

# %% [markdown]
# - answer_relevancy ≥ 0.8 이면 FAQ 일치율 양호   낮으면 프롬프트/쿼리 확장/리트리버 k값 조정.
#
# - faithfulness < 0.9 라면 Prompt 수정·retriever k값 조정 필요, ‘컨텍스트 내 근거 인용’ 지시 강화, 답변 길이 제한, 시스템 프롬프트 보강.
#
# - context_precision 은 1.0에 가까울수록 불필요한 문맥이 적음. 임베딩 모델/토크나이저, 인덱스 파라미터(HNSW, k), 쿼리 재작성 확인.
#
#  OOD(미지원 질문)용 거절 정확도 같은 보조 지표도 추가하면 좋을 듯.

# %% [markdown]
# ## Sample-level (sorted by Faithfulness)

# %%
print(df.sort_values("faithfulness")[[
    "user_input",
    "retrieved_contexts",
    'response',
    "answer_relevancy",
    "faithfulness",
    "llm_context_precision_without_reference"
]])
# Out:
#                       user_input  \
# 3              정기적금 우대이율 조건 요약해줘
# 2  우리 SUPER주거래 적금 3년 만기 금리가 얼마야?
# 5             청년이라면 어떤 예금이 유리할까?
# 0          OTP 비밀번호 오류 해제 방법 알려줘
# 4              나에게 맞는 적금 상품 추천해줘
# 1        해외에서 인터넷뱅킹 이용 시 주의할 점은?
#
#                                   retrieved_contexts  \
# 3  [Q: 가족이 방문하여 정기예금 만기해지를 대신 할 수 있나요?\nA: 예금해지는 ...
# 2  [Q: 현재 거주하고 있는 전세주택의 임대차계약으로도 전세대출이 가능한가요?\nA:...
# 5  [Q: 미성년자 본인 예금가입 시 부모님과 함께 가야하나요?\nA: 만 14세 이상...
# 0  [Q: 보안카드(OTP발생기) 비밀번호 오입력횟수가 초과되었어요. 인터넷뱅킹에서 오...
# 4  [Q: 어떤 펀드가 전문가 포트폴리오에 추천되나요?\nA: 우리은행에서 자체개발한 ...
# 1  [Q: 해외에서 인터넷/스마트뱅킹을 이용하려면 출국하기 전에 확인할 사항이 있나요?...
#
#                                             response  answer_relevancy  \
# 3  추가 확인 필요. <context>에는 정기적금 우대이율 조건에 대한 정보가 포함되...          0.000000
# 2  해당 내용은 담당 직원 확인 후 안내하겠습니다(②). 추가적인 정보가 필요하시면 언...          0.000000
# 5  청년에게 유리한 예금 상품으로는 '청년희망적금'과 '청년 주택드림 청약통장'이 있습...          0.471018
# 0  OTP 비밀번호 오류 해제 방법은 다음과 같습니다:\n\n1. 우리WON뱅킹에 접속...          0.696997
# 4  고객님의 상황에 따라 적합한 적금 상품을 추천해드리겠습니다.\n\n1. **우리 퍼...          0.000000
# 1  해외에서 인터넷뱅킹을 이용할 때 주의할 점은 다음과 같습니다.\n\n1. 해외IP차...          0.533919
#
#    faithfulness  llm_context_precision_without_reference
# 3           0.0                                 0.190794
# 2           0.0                                 0.000000
# 5           0.7                                 0.070455
# 0           0.8                                 0.666667
# 4           0.8                                 0.601951
# 1           1.0                                 0.840476

# %% [markdown]
# ## Example

# %%
for i in range(5):
    print('\nuser_input:',df['user_input'][i])
    print('retrieved_contexts:',df['retrieved_contexts'][i])
    print('response:',df['response'][i])
    print('='*120)
# Out:
# user_input: OTP 비밀번호 오류 해제 방법 알려줘
# retrieved_contexts: ['Q: 보안카드(OTP발생기) 비밀번호 오입력횟수가 초과되었어요. 인터넷뱅킹에서 오류해제 가능한가요?\nA: 보안카드 비밀번호 연속 3회 또는 OTP발생기 비밀번호 연속 10회 오입력 초과 시 보안매체를 이용할 수 없습니다. 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 가능합니다. (인터넷뱅킹에서는 불가)', 'Q: 이용자비밀번호 3회 오류 상태인데, 인터넷뱅킹에서 오류 해제 할 수 있나요?\nA: 기존 이용자비밀번호를 알고 있다면 인터넷뱅킹에서 오류해제 할 수 있습니다. (보안매체 및 인증서 입력 필요)', '▶ 인터넷뱅킹 경로 안내 : 개인뱅킹 로그인→ (아이디 로그인 영역) 비밀번호 재등록→ 이용자비밀번호 3회 오류해제', '※ 이용자비밀번호 3회오류인 경우, 아이디로그인은 불가하나 인증서 등 다른 방법의 로그인은 가능합니다.(법인 제외)', '※ 인터넷뱅킹에서 오류해제가 불가하다면, 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 및 비밀번호 재등록을 할 수 있습니다.', 'Q: 이용자비밀번호(로그인비밀번호) 2회 오류 상태인데, 인터넷뱅킹에서 재등록 할 수 있나요?\nA: 인터넷뱅킹에서 이용자비밀번호 재등록이 가능하며, 보안매체와 인증서 입력이 필요합니다.', '', '▶ 이용자비밀번호 재등록 경로 안내 : 개인인터넷뱅킹 → (아이디 로그인 영역) 비밀번호재등록 → 이용자비밀번호 재등록', '', '※ 인터넷뱅킹에서 재등록 불가하다면, 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 및 비밀번호 재등록을 할 수 있습니다.']
# response: OTP 비밀번호 오류 해제 방법은 다음과 같습니다:
#
# 1. 우리WON뱅킹에 접속합니다.
# 2. 비대면 실명확인 절차를 진행합니다.
# 3. 오류가 해제된 후, 필요한 경우 비밀번호를 재등록합니다.
#
# ※ 인터넷뱅킹에서는 OTP 비밀번호 오류 해제가 불가능합니다(①).
# ========================================================================================================================
#
# user_input: 해외에서 인터넷뱅킹 이용 시 주의할 점은?
# retrieved_contexts: ['Q: 해외에서 인터넷/스마트뱅킹을 이용하려면 출국하기 전에 확인할 사항이 있나요?\nA: 해외 출국 전 아래 사항을 확인 바랍니다.\n1) 해외IP차단서비스 해제 (필수)', '2) 단말기지정서비스 해제 또는 미지정기기 옵션 허용 권장', '3) OTP발생기(디지털OTP) 사용자는 보안카드 지참 권장', '- 고장, 분실 등 비상시 보안매체를 보안카드로 변경 가능(단, 전자뱅킹 이체한도 하향될 수 있음)', '4) 금융인증서/우리WON인증서 사용자는 공동인증서 추가 발급 권장', '5) 비밀번호 오류상태 사전 체크', '6) 전자뱅킹 이체한도 및 이용하려는 계좌 상태(한도제한 등) 확인', '7) 은행에 등록된 고객정보(성명, 연락처 등) 정비', '', '※ 국내통신망이 아닌 경우 이용이 불가할 수 있으며, 국내통신망을 이용하더라도 현지 통신망 상황에 따라 일부 제한될 수 있습니다.', 'Q: 이용자비밀번호 3회 오류 상태인데, 인터넷뱅킹에서 오류 해제 할 수 있나요?\nA: 기존 이용자비밀번호를 알고 있다면 인터넷뱅킹에서 오류해제 할 수 있습니다. (보안매체 및 인증서 입력 필요)', '▶ 인터넷뱅킹 경로 안내 : 개인뱅킹 로그인→ (아이디 로그인 영역) 비밀번호 재등록→ 이용자비밀번호 3회 오류해제', '※ 이용자비밀번호 3회오류인 경우, 아이디로그인은 불가하나 인증서 등 다른 방법의 로그인은 가능합니다.(법인 제외)', '※ 인터넷뱅킹에서 오류해제가 불가하다면, 우리WON뱅킹에서 비대면 실명확인 절차로 오류해제 및 비밀번호 재등록을 할 수 있습니다.', 'Q: 인터넷뱅킹을 오랫동안 이용하지 않아서 자금이체가 제한되었다고 나와요. 인터넷뱅킹에서 해제 하는 방법이 있나요?\nA: 12개월이상 인터넷/스마트뱅킹을 통한 로그인 등 이용이 없는 경우 장기미사용으로 자금이체 거래가 제한됩니다. 인터넷뱅킹에서 자금이체 거래제한을 해제 할 수 있으며. 보안매체 및 인증서 입력이 필요합니다.', '▶ 자금이체제한/해제 경로 안내 : 개인인터넷뱅킹 → 뱅킹관리 → 인터넷뱅킹관리 → 자금이체제한/해제', '※ 우리WON뱅킹에서도 자금이체제한해제 가능합니다.']
# response: 해외에서 인터넷뱅킹을 이용할 때 주의할 점은 다음과 같습니다.
#
# 1. 해외IP차단서비스 해제 (필수)
# 2. 단말기지정서비스 해제 또는 미지정기기 옵션 허용 권장
# 3. OTP발생기(디지털OTP) 사용자는 보안카드 지참 권장 (고장, 분실 시 보안매체를 보안카드로 변경 가능, 단 이체한도 하향 가능)
# 4. 금융인증서/우리WON인증서 사용자는 공동인증서 추가 발급 권장
# 5. 비밀번호 오류상태 사전 체크
# 6. 전자뱅킹 이체한도 및 이용하려는 계좌 상태(한도제한 등) 확인
# 7. 은행에 등록된 고객정보(성명, 연락처 등) 정비
#
# ※ 국내통신망이 아닌 경우 이용이 불가할 수 있으며, 현지 통신망 상황에 따라 일부 제한될 수 있습니다. (①)
# ========================================================================================================================
#
# user_input: 우리 SUPER주거래 적금 3년 만기 금리가 얼마야?
# retrieved_contexts: ['Q: 현재 거주하고 있는 전세주택의 임대차계약으로도 전세대출이 가능한가요?\nA: 거주중인 전세주택의 경우는 거주기간, 보증금 증액 여부 등 자금의 용도에 따라 가능 할 수 있습니다.', '단, 상품의 대출 대상자요건, 주택요건, 소득 및 부채 등의 요건에 따라 달라질 수 있으므로 자세한 대출상품 내용은 홈페이지를 참고하여 주시기 바랍니다.', '', '▶ 전세자금대출 신청시기', '① 주택도시기금 전세자금대출', '- 신규자금 : 임대차계약서상 잔금지급일과 주민등록등본상 전입일 중 빠른날로부터 3개월 이내', '- 계약갱신 : 전입일로부터 1년 이상 경과하고, 계약갱신일로부터 3개월 이내(보증금 증액이 있는 경우만 가능)', '(단, 공공임대는 전입일로부터 3개월 이상 경과하고, 계약갱신일로부터 3개월 이내로 보증금이 증액된 경우 가능)', '② 은행 전세자금대출', '- 신규자금 : 임대차계약서상 잔금지급일과 주민등록등본상 전입일 중 빠른날로부터 3개월 이내', '- 계약갱신 : 전입일로부터 3개월 이상 경과하고, 계약갱신일로부터 3개월 이내(보증금 증액이 없는 경우에도 가능)', 'Q: 인터넷뱅킹을 오랫동안 이용하지 않아서 자금이체가 제한되었다고 나와요. 인터넷뱅킹에서 해제 하는 방법이 있나요?\nA: 12개월이상 인터넷/스마트뱅킹을 통한 로그인 등 이용이 없는 경우 장기미사용으로 자금이체 거래가 제한됩니다. 인터넷뱅킹에서 자금이체 거래제한을 해제 할 수 있으며. 보안매체 및 인증서 입력이 필요합니다.', '▶ 자금이체제한/해제 경로 안내 : 개인인터넷뱅킹 → 뱅킹관리 → 인터넷뱅킹관리 → 자금이체제한/해제', '※ 우리WON뱅킹에서도 자금이체제한해제 가능합니다.', 'Q: 연금저축펀드가 무엇인가요?\nA: 소득세법에 따라 도입된 제도로 일정 기간 입금 후 연금형태로 찾을 경우 연금소득으로 과세하는', '세제 혜택 금융상품이에요. 최소 5년이상 가입하고, 10년이상 연금을 지급받을 수 있어요.', '입금하는 기간 동안에는 연간 600만원 한도 내에서 세액공제가 가능해요.', '및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품', '달라질 수 있습니다.\n⋅만기 전 해지할 경우 약정한 이율보다 낮은 중도해지이율이 적용됩니다.\n⋅우대금리는 만기 해지 시에만 적용되며, 중도해지하는 경우 적용되지 않습니다.\n⋅’19.7.19.부터 “위비SUPER주거래적금Ⅱ”에서 “우리 SUPER주거래 적금”으로 변경되었습니다.\n  기존에 “위비SUPER주거래적금Ⅱ”를 가입한 고객님께서도 상품명이 “우리 SUPER주거래 적금”  \n  으로 변경되며, 우대이율은 시행일 이후 가입자에 대해서 변경된 상품 내용을 \n  적용받게 됩니다.\n⋅금리변동형 정기적금은 금리상승기에 약정금리 인상 가능성이 큰 반면, 금리 하락기에는 \n   약정금리 인하로 소비자에게 불리할 수 있습니다.', '보통위험\n 우리 일임형 고배당30 ISA(위험중립형)\n투자에는 그에 상응하는 투자위험이 있음을 충분히 인지하고, 예‧적금보다 높은 수\n익을 기대할 수 있다면 일정 수준의 위험을 감수할 수 있는 투자자에게 적합한 상\n품입니다.\n 우리 일임형 글로벌30 ISA(위험중립형)\n 우리 일임형 공모주알파 ISA(위험중립형)\n낮은위험\n 우리 일임형 회사채 ISA(안정추구형)\n투자원금의 손실위험은 최소화하고, 이자소득이나 배당소득 수준의 안정적인 투자를 \n목표로 하는 투자자에게 적합한 상품입니다.\n 우리 일임형 국공채 ISA(안정추구형)\n 우리 일임형 우량채 ISA(안정추구형)\n매우낮은위험\n 우리 일임형 안정형 ISA(안정형)\n예금 또는 적금 수준의 수익률을 기대하며, 투자원금에 손실이 발생하는 것을 원하지']
# response: 해당 내용은 담당 직원 확인 후 안내하겠습니다(②). 추가적인 정보가 필요하시면 언제든지 문의해 주세요.
# ========================================================================================================================
#
# user_input: 정기적금 우대이율 조건 요약해줘
# retrieved_contexts: ['Q: 가족이 방문하여 정기예금 만기해지를 대신 할 수 있나요?\nA: 예금해지는 본인이 방문하여 본인의사 확인 후 해지가 원칙입니다.', '다만, 부득이한 경우 적법한 위임관계가 확인되면대리인에 의한 해지가 가능할 수 있으므로방문하실 영업점으로 상담받아 보시기 바랍니다.', 'Q: 비과세종합저축 가입자격과 가입한도가 궁금해요.\nA: 전 금융기관을 통하여 5천만원 범위 내의 저축에서 발생하는 이자와 배당소득에 대하여 저축상품의 가입기간 관계없이 만기일 까지', '비과세 혜택을 부여하는 제도입니다.', '', '[가입자격]', '① 만 65세 이상인 거주자', '② 「장애인복지법」제 32조에 따라 등록한 장애인', '③ 「독립유공자 예우에 관한 법률」제 6조에 따라 등록한 독립유공자와 그 유족 또는 가족', '④ 「국가유공자 등 예우 및 지원에 관한 법률」제 6조에 따라 등록한 상이자', '⑤ 「국민기초생활보장법」제 2조 제 2호에 따른 수급자', '⑥ 「고엽제후유의증 환자지원 등에 관한 법률」제 2조 제3호에 따른 고엽제후유의증환자', '⑦ 「5·18 민주유공자 예우에 관한 법률」제 4조 제2호에 따른 5.18민주화운동 부상자', '[가입한도]', '- 1인당 원금을 합하여 5천만원 이내', '- 기 가입한 세금우대저축, 생계형저축한도를 포함한 통합한도', '- 가입한도내 다수 계좌 개설 가능', '[가입시한]', '- 2025년 12월 31까지 가입 가능합니다.', '- 2020년 1월 1일 이후 비과세종합저축 가입자는 소득요건을 충족하지 못할 경우 불이익을 받을 수 있음', '- 소득요건 추가 : 직전 3개 과세기간 內 1회 이상 금융소득종합과세 대상자는 제외', '(종합소득 종합과세 대상자는 금융소득 연간 합계액이 2천만원을 초과하는 경우임)', 'Q: 인터넷뱅킹에서 정기예금, 적금을 담보로 대출이 가능한가요?\nA: 네, 가능합니다.', '▶ 가능금액 : 예·적금 잔액의 95%이내 (단, 10만원 단위로 가능합니다.)', '▶ 적용금리 : 예·적금 수신금리 + 1.0%', '▶ 인터넷뱅킹 경로 :대출 → 인터넷대출신청 → 예금담보대출 → 대출신청', '※ 유의사항', '①예·적금 가입일 포함 3영업일째부터 가능합니다.', '②일부상품은 담보대출이 불가할 수 있습니다.', '③인터넷뱅킹에서 예적금담보대출의 최고한도는 1억원까지 가능합니다.']
# response: 추가 확인 필요. <context>에는 정기적금 우대이율 조건에 대한 정보가 포함되어 있지 않습니다.
# ========================================================================================================================
#
# user_input: 나에게 맞는 적금 상품 추천해줘
# retrieved_contexts: ['Q: 어떤 펀드가 전문가 포트폴리오에 추천되나요?\nA: 우리은행에서 자체개발한 투자상품 평가모델(WISE)을 활용, 정량적 평가(우량 상품 선별)와 정성적 평가(경제 및 시장 전망)을 합쳐 포트폴리오 우선 편입 상품을 결정하여 추천드립니다', 'Q: 나의 투자성향 등급 상품만 가입가능한가요?\nA: 투자성향 등급상품만 가입 가능한건 아니에요.', '내 성향 이하(예: 위험중립형인 경우, 안정형과 안정추구형도 신규가능)의 추천 포트폴리오도 선택가능합니다.', 'Q: 연금저축펀드 가입 및 해지시 어떤부분을 유의해야할까요?\nA: 연금저축펀드 운용 중 연금수령방법이 아닌 연금 외 수령방법으로 일부 또는 전부해지를 할 경우', '세액공제 받은 금액과 운용수익에 대해 기타소득세 16.5%가 부과돼요. 따라서 장기적으로 운용해야  하는 상품이니 투자자의 자산 및 소득 등 재정 상태를 고려하여 가입하는 것이 좋아요.', '부득이 일부 또는 전부해지를 할 경우 세액공제 받은 금액을 확인하여, 세액공제를 안받았거나', '입금액보다 적게 세액공제를 받았으면 과세제외 요청을 별도 신청하셔야 해요.', '및 특징\n⋅상 품 명 : 「우리 퍼스트 적금2」\n⋅상품특징 : 우리은행 신규 고객님과 직전 6개월동안 예·적금을 미보유한 고객님께\n우대금리를 제공하는 적립식 상품', '있습니다.\n   ※ 본 서류는 법령 및 내부통제기준에 따른 절차를 걸쳐 금융소비자에게 제공되는 문서입니다.\n 이 상품은 우리은행 개인금융솔루션부에서 개발한 상품입니다. 본 상품에 대한 문의사항 또는 민원 \n상담이 필요하시면 영업점, 우리은행 고객센터(1588-5000), 우리은행 홈페이지(www.wooribank.com)를 \n통해 문의주시기 바랍니다. 또한 본 상품에 대하여 당 은행과 분쟁이 있는 경우에는 금융소비자보호법에 \n따라 금융감독원 민원상담 센터(국번없이 1332) 또는 e-금융민원센터(https://www.fcsc.kr)에 분쟁조정을 \n신청할 수 있습니다.\n<부록> 예금상품 설명을 위한 관련 용어 안내\n용어\n설명\n압류\n▪ 채무자의 특정한 재산에 대하여 처분(매매, 양도 등)을 금지하게', '및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품', '및 특징\n⋅상 품 명 : 「우리 Magic 적금 by 롯데카드」\n⋅상품특징 : 우리은행과 롯데카드 거래실적에 따른 우대금리를 제공하는 상품', '’22.1.1 ~ ’22.12.31\n(납입원금+은행이자+1%이자지원금) X 33%\n’23.1.1 ~ ’23.12.31\n(납입원금+은행이자+1%이자지원금) X 71%\n’24.1.1 이후\n납입원금 X 100%\n<별지> 「우리 장병내일준비적금」연계·제휴서비스\n구  분\n내   용\n비 고\n연계/제휴\n서비스 내용 \n(무료상해보험)\n • 제공기준 : 적금 신규 시점주1)에 아래 ①,② 조건을 모두 \n   충족하는 경우 \n   ① 우리은행 통장에서 이 적금으로 자동이체 등록\n   ② 우리은행 주택청약종합저축 상품 가입 고객 \n  ※ 주1) 이 상품의 신규월\n • 무료상해보험(DB손해보험 제공) 가입 서비스 \n  - 보장기간 : 적금 신규가입 다음 월 15일부터 21개월 동안 제공', '예금자보호\nX\n‣ 주택도시기금의 조성재원으로 정부가 관리\n ‣ 유의사항\n ※ 상품 관련 특약 및 상품설명서를 확인하신 후, 상품 가입 전 궁금하신 사항은 \n   반드시 우리은행 영업점 혹은 고객센터(☎1588-5000)로 문의하시기 바랍니다.']
# response: 고객님의 상황에 따라 적합한 적금 상품을 추천해드리겠습니다.
#
# 1. **우리 퍼스트 적금2**: 신규 고객님이나 직전 6개월 동안 예·적금을 미보유한 고객님께 우대금리를 제공하는 적립식 상품입니다. 이러한 조건에 해당하신다면 이 상품이 적합할 수 있습니다.
#
# 2. **우리 SUPER주거래 적금**: 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품입니다. 이미 우리은행에서 거래를 하고 계신다면 이 상품이 좋을 수 있습니다.
#
# 3. **우리 Magic 적금 by 롯데카드**: 우리은행과 롯데카드 거래실적에 따른 우대금리를 제공하는 상품입니다. 롯데카드를 사용하고 계신다면 이 상품도 고려해볼 수 있습니다.
#
# 고객님의 구체적인 상황이나 필요에 따라 더 자세한 상담이 필요하시면 우리은행 영업점이나 고객센터(1588-5000)로 문의하시기 바랍니다.
#
# ---
# 아직 가입 상담 기능은 PoC 단계입니다.
# 예금/적금 기본 정보를 먼저 확인해 봐주세요!
# ========================================================================================================================
