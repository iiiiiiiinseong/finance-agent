# %% [markdown]
# # E2E 테스트 – Product RAG PoC
#
# 1. '.env' 로부터 OpenAI 키 로딩
# 2.  woori_deoposit → FAISS 인덱스 생성
# 3. LangGraph product 파이프라인 로드
# 4. 샘플 질의에 대한 응답 생성
# 5. RAGAS 평가로 정확도·신뢰도 확인

# %%
# 1. env & 라이브러리
from pathlib import Path
from dotenv import load_dotenv
import os, json, pprint, sys, pandas as pd

ROOT = Path.cwd().parent  # 노트북은 tests/ 하위에 있다고 가정
sys.path.append(str(ROOT))

load_dotenv(ROOT / ".env")
print(f"ROOT - {ROOT}")
print("환경 변수 로드 완료")
# Out:
# ROOT - c:\Users\insung\Finance_Agent
# 환경 변수 로드 완료

# %%
# 2. 인덱스 준비
from scripts.build_deposit_index import build_index

build_index()
# Out:
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '수수료'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '중도해지'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '가입방법'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '수수료'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '수수료'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '수수료'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '수수료'} - chunk lenght: 14
# meta_base: {'product_code': 'PLM_P00XXXXXXX', 'file_date': '2025-03-31', 'product': '- 1 -', 'section': '유의사항'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P010000002', 'file_date': '2025-07-29', 'product': '', 'section': '중도해지'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010000002', 'file_date': '2025-07-29', 'product': '', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000002', 'file_date': '2025-07-29', 'product': '', 'section': '중도해지'} - chunk lenght: 12
# meta_base: {'product_code': 'PLM_P010000013', 'file_date': '2025-04-29', 'product': '\x01 \x01', 'section': '기타'} - chunk lenght: 48
# meta_base: {'product_code': 'PLM_P010000054', 'file_date': '2024-12-12', 'product': '「마이스타일 자유적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000054', 'file_date': '2024-12-12', 'product': '「마이스타일 자유적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010000054', 'file_date': '2024-12-12', 'product': '「마이스타일 자유적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000054', 'file_date': '2024-12-12', 'product': '「마이스타일 자유적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010000109', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000109', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010000109', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000109', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010000110', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000110', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010000110', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000110', 'file_date': '2025-06-19', 'product': '「우리 SUPER주거래 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010000112', 'file_date': '2025-04-29', 'product': '준법감시인 심의필 2025-4035(2025.04.24~2027.03.31)', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000112', 'file_date': '2025-04-29', 'product': '준법감시인 심의필 2025-4035(2025.04.24~2027.03.31)', 'section': '거래 조건'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000112', 'file_date': '2025-04-29', 'product': '준법감시인 심의필 2025-4035(2025.04.24~2027.03.31)', 'section': '중도해지'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010000196', 'file_date': '2025-06-19', 'product': '「정기예금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000196', 'file_date': '2025-06-19', 'product': '「정기예금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010000196', 'file_date': '2025-06-19', 'product': '「정기예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010000223', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '상품 개요'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000223', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010000223', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '중도해지'} - chunk lenght: 17
# meta_base: {'product_code': 'PLM_P010000223', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000224', 'file_date': '2025-04-29', 'product': '준법감시인 심의필 2025-4036 (2025.04.24~2027.03.31)', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000224', 'file_date': '2025-04-29', 'product': '준법감시인 심의필 2025-4036 (2025.04.24~2027.03.31)', 'section': '거래 조건'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000224', 'file_date': '2025-04-29', 'product': '준법감시인 심의필 2025-4036 (2025.04.24~2027.03.31)', 'section': '중도해지'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010000225', 'file_date': '2024-12-12', 'product': '「우리사랑 정기적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000225', 'file_date': '2024-12-12', 'product': '「우리사랑 정기적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010000225', 'file_date': '2024-12-12', 'product': '「우리사랑 정기적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000225', 'file_date': '2024-12-12', 'product': '「우리사랑 정기적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P010000240', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '상품 개요'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000240', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010000240', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '중도해지'} - chunk lenght: 17
# meta_base: {'product_code': 'PLM_P010000240', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13182(2024.12.27~2026.11.30)', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000301', 'file_date': '2025-02-26', 'product': '「우리 자유적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000301', 'file_date': '2025-02-26', 'product': '「우리 자유적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010000301', 'file_date': '2025-02-26', 'product': '「우리 자유적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000301', 'file_date': '2025-02-26', 'product': '「우리 자유적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010000305', 'file_date': '2025-06-19', 'product': '「정기적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000305', 'file_date': '2025-06-19', 'product': '「정기적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010000305', 'file_date': '2025-06-19', 'product': '「정기적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010000305', 'file_date': '2025-06-19', 'product': '「정기적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P010000361', 'file_date': '2025-06-19', 'product': '「두루두루정기예금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000361', 'file_date': '2025-06-19', 'product': '「두루두루정기예금」상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010000361', 'file_date': '2025-06-19', 'product': '「두루두루정기예금」상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010000364', 'file_date': '2025-06-19', 'product': '「CD플러스 예금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000364', 'file_date': '2025-06-19', 'product': '「CD플러스 예금」상품설명서', 'section': '거래 조건'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000364', 'file_date': '2025-06-19', 'product': '「CD플러스 예금」상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010000399', 'file_date': '2025-06-19', 'product': '「우리사랑나누美적금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010000399', 'file_date': '2025-06-19', 'product': '「우리사랑나누美적금」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010000399', 'file_date': '2025-06-19', 'product': '「우리사랑나누美적금」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010000399', 'file_date': '2025-06-19', 'product': '「우리사랑나누美적금」상품설명서', 'section': '중도해지'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P010002121', 'file_date': '2024-12-19', 'product': '「우리Champ이자율구조화복합예금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002121', 'file_date': '2024-12-19', 'product': '「우리Champ이자율구조화복합예금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002121', 'file_date': '2024-12-19', 'product': '「우리Champ이자율구조화복합예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002121', 'file_date': '2024-12-19', 'product': '「우리Champ이자율구조화복합예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002121', 'file_date': '2024-12-19', 'product': '「우리Champ이자율구조화복합예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002121', 'file_date': '2024-12-19', 'product': '「우리Champ이자율구조화복합예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 17
# meta_base: {'product_code': 'PLM_P010002283', 'file_date': '2025-07-21', 'product': '우리은행 『장병내일준비적금』 요약설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002283', 'file_date': '2025-07-21', 'product': '우리은행 『장병내일준비적금』 요약설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002283', 'file_date': '2025-07-21', 'product': '우리은행 『장병내일준비적금』 요약설명서', 'section': '거래 조건'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002283', 'file_date': '2025-07-21', 'product': '우리은행 『장병내일준비적금』 요약설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002283', 'file_date': '2025-07-21', 'product': '우리은행 『장병내일준비적금』 요약설명서', 'section': '수수료'} - chunk lenght: 23
# meta_base: {'product_code': 'PLM_P010002293', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13187(2024.12.27~2025.12.31)', 'section': '상품 개요'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002293', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13187(2024.12.27~2025.12.31)', 'section': '거래 조건'} - chunk lenght: 53
# meta_base: {'product_code': 'PLM_P010002293', 'file_date': '2024-12-30', 'product': '준법감시인 심의필 2024-13187(2024.12.27~2025.12.31)', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002353', 'file_date': '2025-06-19', 'product': '「WON 적금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002353', 'file_date': '2025-06-19', 'product': '「WON 적금」상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002353', 'file_date': '2025-06-19', 'product': '「WON 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002353', 'file_date': '2025-06-19', 'product': '「WON 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 8
# MuPDF error: syntax error: invalid key in dict
#
# MuPDF error: syntax error: invalid key in dict
#
# meta_base: {'product_code': 'PLM_P010002366', 'file_date': '2025-01-09', 'product': '「통합이지바로 연구비 수행 전용계좌」 핵심설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002366', 'file_date': '2025-01-09', 'product': '「통합이지바로 연구비 수행 전용계좌」 핵심설명서', 'section': '거래 조건'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002366', 'file_date': '2025-01-09', 'product': '「통합이지바로 연구비 수행 전용계좌」 핵심설명서', 'section': '유의사항'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010002373', 'file_date': '2025-06-30', 'product': '「우리 (업체명 임직원) 적금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002373', 'file_date': '2025-06-30', 'product': '「우리 (업체명 임직원) 적금」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002373', 'file_date': '2025-06-30', 'product': '「우리 (업체명 임직원) 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002385', 'file_date': '2025-06-18', 'product': '', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002385', 'file_date': '2025-06-18', 'product': '', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002385', 'file_date': '2025-06-18', 'product': '', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002385', 'file_date': '2025-06-18', 'product': '', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002385', 'file_date': '2025-06-18', 'product': '', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002402', 'file_date': '2025-06-20', 'product': '「우리 SUPER 정기예금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002402', 'file_date': '2025-06-20', 'product': '「우리 SUPER 정기예금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002402', 'file_date': '2025-06-20', 'product': '「우리 SUPER 정기예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 12
# meta_base: {'product_code': 'PLM_P010002403', 'file_date': '2025-06-20', 'product': '「우리 SUPER 정기예금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002403', 'file_date': '2025-06-20', 'product': '「우리 SUPER 정기예금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002403', 'file_date': '2025-06-20', 'product': '「우리 SUPER 정기예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 12
# meta_base: {'product_code': 'PLM_P010002406', 'file_date': '2024-12-31', 'product': '「우리 Magic 적금 by 롯데카드」', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002406', 'file_date': '2024-12-31', 'product': '「우리 Magic 적금 by 롯데카드」', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002406', 'file_date': '2024-12-31', 'product': '「우리 Magic 적금 by 롯데카드」', 'section': '거래 조건'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002406', 'file_date': '2024-12-31', 'product': '「우리 Magic 적금 by 롯데카드」', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002406', 'file_date': '2024-12-31', 'product': '「우리 Magic 적금 by 롯데카드」', 'section': '중도해지'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P010002406', 'file_date': '2024-12-31', 'product': '「우리 Magic 적금 by 롯데카드」', 'section': '중도해지'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002408', 'file_date': '2024-12-12', 'product': '「첫급여 우리적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002408', 'file_date': '2024-12-12', 'product': '「첫급여 우리적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002408', 'file_date': '2024-12-12', 'product': '「첫급여 우리적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002408', 'file_date': '2024-12-12', 'product': '「첫급여 우리적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002448', 'file_date': '2024-12-12', 'product': '「우리 으쓱(ESG) 적금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002448', 'file_date': '2024-12-12', 'product': '「우리 으쓱(ESG) 적금」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002448', 'file_date': '2024-12-12', 'product': '「우리 으쓱(ESG) 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002448', 'file_date': '2024-12-12', 'product': '「우리 으쓱(ESG) 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '거래 조건'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '거래 조건'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '거래 조건'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002482', 'file_date': '2025-05-29', 'product': '「우리 (영업점명) 적금 (기본형)」상품설명서', 'section': '중도해지'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002487', 'file_date': '2025-05-12', 'product': '「우리 첫거래우대 정기예금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002487', 'file_date': '2025-05-12', 'product': '「우리 첫거래우대 정기예금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010002487', 'file_date': '2025-05-12', 'product': '「우리 첫거래우대 정기예금」 상품설명서', 'section': '중도해지'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '상품특징'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002494', 'file_date': '2025-06-19', 'product': '「우리 아이행복 적금2」 핵심설명서', 'section': '수수료'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002507', 'file_date': '2025-04-04', 'product': '「우리 퍼스트 정기적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002507', 'file_date': '2025-04-04', 'product': '「우리 퍼스트 정기적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002507', 'file_date': '2025-04-04', 'product': '「우리 퍼스트 정기적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002507', 'file_date': '2025-04-04', 'product': '「우리 퍼스트 정기적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002512', 'file_date': '2025-07-21', 'product': '「우리 청년도약계좌」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002512', 'file_date': '2025-07-21', 'product': '「우리 청년도약계좌」 상품설명서', 'section': '거래 조건'} - chunk lenght: 15
# meta_base: {'product_code': 'PLM_P010002512', 'file_date': '2025-07-21', 'product': '「우리 청년도약계좌」 상품설명서', 'section': '중도해지'} - chunk lenght: 20
# meta_base: {'product_code': 'PLM_P010002514', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002514', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002514', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002514', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002514', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002515', 'file_date': '2025-07-08', 'product': '「N일 적금(100일)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002515', 'file_date': '2025-07-08', 'product': '「N일 적금(100일)」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002515', 'file_date': '2025-07-08', 'product': '「N일 적금(100일)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002515', 'file_date': '2025-07-08', 'product': '「N일 적금(100일)」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002515', 'file_date': '2025-07-08', 'product': '「N일 적금(100일)」상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002516', 'file_date': '2025-07-08', 'product': '「N일 적금(200일)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002516', 'file_date': '2025-07-08', 'product': '「N일 적금(200일)」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002516', 'file_date': '2025-07-08', 'product': '「N일 적금(200일)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002516', 'file_date': '2025-07-08', 'product': '「N일 적금(200일)」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002516', 'file_date': '2025-07-08', 'product': '「N일 적금(200일)」상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002517', 'file_date': '2025-07-08', 'product': '「N일 적금(31일)」상품설명서', 'section': '중도해지'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002530', 'file_date': '2025-07-15', 'product': '「원비즈플라자 멤버십 적금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002530', 'file_date': '2025-07-15', 'product': '「원비즈플라자 멤버십 적금」상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002530', 'file_date': '2025-07-15', 'product': '「원비즈플라자 멤버십 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002532', 'file_date': '2025-02-27', 'product': '「다목적 자금관리 결제통장」 핵심설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002532', 'file_date': '2025-02-27', 'product': '「다목적 자금관리 결제통장」 핵심설명서', 'section': '거래 조건'} - chunk lenght: 10
# meta_base: {'product_code': 'PLM_P010002550', 'file_date': '2025-06-19', 'product': '「머니클립 통장」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002550', 'file_date': '2025-06-19', 'product': '「머니클립 통장」상품설명서', 'section': '거래 조건'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002550', 'file_date': '2025-06-19', 'product': '「머니클립 통장」상품설명서', 'section': '가입방법'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002550', 'file_date': '2025-06-19', 'product': '「머니클립 통장」상품설명서', 'section': '수수료'} - chunk lenght: 19
# meta_base: {'product_code': 'PLM_P010002556', 'file_date': '2025-06-04', 'product': '「CJ PAY 우리 통장」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002556', 'file_date': '2025-06-04', 'product': '「CJ PAY 우리 통장」상품설명서', 'section': '거래 조건'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002556', 'file_date': '2025-06-04', 'product': '「CJ PAY 우리 통장」상품설명서', 'section': '가입방법'} - chunk lenght: 4
# meta_base: {'product_code': 'PLM_P010002556', 'file_date': '2025-06-04', 'product': '「CJ PAY 우리 통장」상품설명서', 'section': '수수료'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002556', 'file_date': '2025-06-04', 'product': '「CJ PAY 우리 통장」상품설명서', 'section': '수수료'} - chunk lenght: 13
# meta_base: {'product_code': 'PLM_P010002562', 'file_date': '2025-03-27', 'product': '「우월한 월급 통장」 핵심 상품설명서', 'section': '상품특징'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002562', 'file_date': '2025-03-27', 'product': '「우월한 월급 통장」 핵심 상품설명서', 'section': '수수료'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002562', 'file_date': '2025-03-27', 'product': '「우월한 월급 통장」 핵심 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002562', 'file_date': '2025-03-27', 'product': '「우월한 월급 통장」 핵심 상품설명서', 'section': '거래 조건'} - chunk lenght: 6
# meta_base: {'product_code': 'PLM_P010002562', 'file_date': '2025-03-27', 'product': '「우월한 월급 통장」 핵심 상품설명서', 'section': '수수료'} - chunk lenght: 11
# meta_base: {'product_code': 'PLM_P010002563', 'file_date': '2025-04-29', 'product': '「우리 내리사랑 적금」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002563', 'file_date': '2025-04-29', 'product': '「우리 내리사랑 적금」상품설명서', 'section': '거래 조건'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P010002563', 'file_date': '2025-04-29', 'product': '「우리 내리사랑 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002563', 'file_date': '2025-04-29', 'product': '「우리 내리사랑 적금」상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002564', 'file_date': '2025-06-13', 'product': '「우리 SAFE 예치통장」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002564', 'file_date': '2025-06-13', 'product': '「우리 SAFE 예치통장」상품설명서', 'section': '거래 조건'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P010002564', 'file_date': '2025-06-13', 'product': '「우리 SAFE 예치통장」상품설명서', 'section': '유의사항'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002565', 'file_date': '2025-05-26', 'product': '「우리 더모아 사업자 통장」상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002565', 'file_date': '2025-05-26', 'product': '「우리 더모아 사업자 통장」상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002565', 'file_date': '2025-05-26', 'product': '「우리 더모아 사업자 통장」상품설명서', 'section': '수수료'} - chunk lenght: 9
# meta_base: {'product_code': 'PLM_P010002566', 'file_date': '2025-05-14', 'product': '「우리WON모바일 적금」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002566', 'file_date': '2025-05-14', 'product': '「우리WON모바일 적금」 상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002566', 'file_date': '2025-05-14', 'product': '「우리WON모바일 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002566', 'file_date': '2025-05-14', 'product': '「우리WON모바일 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002566', 'file_date': '2025-05-14', 'product': '「우리WON모바일 적금」 상품설명서', 'section': '중도해지'} - chunk lenght: 8
# meta_base: {'product_code': 'PLM_P010002567', 'file_date': '2025-05-21', 'product': '「우리 퍼스트 적금 2」 상품설명서', 'section': '상품 개요'} - chunk lenght: 1
# meta_base: {'product_code': 'PLM_P010002567', 'file_date': '2025-05-21', 'product': '「우리 퍼스트 적금 2」 상품설명서', 'section': '거래 조건'} - chunk lenght: 5
# meta_base: {'product_code': 'PLM_P010002567', 'file_date': '2025-05-21', 'product': '「우리 퍼스트 적금 2」 상품설명서', 'section': '중도해지'} - chunk lenght: 2
# meta_base: {'product_code': 'PLM_P010002567', 'file_date': '2025-05-21', 'product': '「우리 퍼스트 적금 2」 상품설명서', 'section': '중도해지'} - chunk lenght: 7
# meta_base: {'product_code': 'PLM_P060000452', 'file_date': '2025-07-18', 'product': '- 1 -', 'section': '수수료'} - chunk lenght: 3
# meta_base: {'product_code': 'PLM_P060000452', 'file_date': '2025-07-18', 'product': '- 1 -', 'section': '유의사항'} - chunk lenght: 2
#   0%|          | 0/6 [00:00<?, ?it/s]
# 2025-07-30 13:10:31,908 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 13:10:33,825 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 13:10:36,257 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 13:10:38,498 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 13:10:40,431 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 13:10:41,926 | INFO | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-30 13:10:42,123 | INFO | Loading faiss with AVX2 support.
# 2025-07-30 13:10:42,173 | INFO | Successfully loaded faiss with AVX2 support.
# 2025-07-30 13:10:42,192 | INFO | Failed to load GPU Faiss: name 'GpuIndexIVFFlat' is not defined. Will not load constructor refs for GPU indexes. This is only an error if you're trying to use GPU Faiss.
# 2025-07-30 13:10:42,330 | INFO | FAISS index saved → C:\Users\insung\Finance_Agent\index\deposit_faiss
# > 1,095 chunks indexed

# %%
# 3. 파이프라인 로딩
from services.rag.product_rag.chain import graph

sample_q = "우리사랑정기적금 3년 만기 기본금리가 얼마나 돼?"
result = graph.invoke({"question": sample_q})
pprint.pp(result)
# Out:
# {'question': '우리사랑정기적금 3년 만기 기본금리가 얼마나 돼?',
#  'answer': '우리사랑정기적금의 3년 만기 기본금리는 연 2.2%입니다(①4).',
#  'context': '기본이율×80%×보유일수/계약일수\n'
#             '11개월 이상 ~ 3년 미만\n'
#             '기본이율×90%×보유일수/계약일수\n'
#             '3년 이상\n'
#             '기본이율\n'
#             '  ※ 기본이율 : 신규(또는 재예치)시점 해당 상품의 기본금리\n'
#             '구 분\n'
#             '내 용\n'
#             '\n'
#             '구분\n'
#             '1개월\n'
#             '3개월\n'
#             '6개월\n'
#             '12개월\n'
#             '24개월\n'
#             '36개월\n'
#             '기본금리\n'
#             '연 2.46%\n'
#             '연 2.49%\n'
#             '연 2.45%\n'
#             '연 2.49%\n'
#             '연 2.37%\n'
#             '연 2.49%\n'
#             '※ 현재 적용금리 확인 : 우리은행 인터넷 홈페이지(www.wooribank.com)\n'
#             '구 분\n'
#             '내 용\n'
#             '이자지급시기\n'
#             '• 만기일시지급식(단리식) : 만기(후) 또는 중도해지 요청시 이자를 지급 \n'
#             '만기이자 \n'
#             '산출근거\n'
#             '• 신규금액 × 약정이율 × (계약일수 ÷ 365일)\n'
#             ' ※ 계약일수는 신규일부터 해지일 전일까지 일수를 의미\n'
#             ' [예시] 신규일 2025.01.10.이고 해지일 2025.4.10.인 경우 계약일수 90일\n'
#             '만기후이율\n'
#             '• 만기일 당시 영업점 및 홈페이지에 고시한 일반 정기예금 만기 후 이율 적용\n'
#             '경과기관\n'
#             '이율\n'
#             '1개월이내\n'
#             '만기시점 약정이자율 × 50%\n'
#             '\n'
#             '☞ 금리 등 아래의 내용은 고객의 이해를 돕기 위하여 약정 전에 제공되는 자료로 실제 계약\n'
#             '     내용은 수령하시는 통장 또는 증서에 따릅니다.\n'
#             '구 분\n'
#             '내 용\n'
#             '가입대상\n'
#             '• 실명의 개인\n'
#             '상품유형\n'
#             '• 정기예금\n'
#             '거래방법\n'
#             '• 신규 : 영업점, 인터넷(스마트)뱅킹\n'
#             '• 해지 : 영업점, 인터넷(스마트)뱅킹\n'
#             '가입금액\n'
#             '• 계좌당 1백만원 이상 \n'
#             '계약기간\n'
#             '• 1개월 이상 ~ 36개월 이하 (월 단위, 일 단위 가입 가능) \n'
#             '기본금리\n'
#             '• 신규일(재예치일)에 고시한 계약기간별 이자율 적용 \n'
#             '                                 (금리기준일: 2025.06.20. 세금납부 전 기준)\n'
#             ' \n'
#             '구분\n'
#             '1개월 이상\n'
#             '3개월 미만\n'
#             '3개월 이상\n'
#             '6개월 미만\n'
#             '6개월 이상\n'
#             '12개월 미만\n'
#             '12개월 이상\n'
#             '24개월 미만\n'
#             '\n'
#             '250\n'
#             '기타시·군\n'
#             '200\n'
#             '이율\n'
#             '3년제\n'
#             '연 2.2%\n'
#             '3년 초과 \n'
#             '5년제\n'
#             '(최초 3년)\n'
#             '3년 지난 시점의 \n'
#             '3년제 약정이율\n'
#             '(기준일:2025.4.30.\n'
#             '세금공제전)\n'
#             '월저축금\n'
#             ' -월 저축금은 납입 회차별 5만원 이상 50만원 이내에서 원단위로 자유롭게 납입\n'
#             ' -월 입금 횟수에 제한은 없으나, 총 입금 횟수는 해당 계약기간의 월수 초과 불가\n'
#             '가입기간\n'
#             ' 3년 또는 5년 (3년 만기 지난 후 당초계약기간 포함 5년으로 연장 가능)\n'
#             '\n'
#             '- 개인형IRP 신규가입자는 계좌 신규 시 사전지정운용방법을 필수로 선정하여야 함\n'
#             ' 사전지정운용방법(디폴트옵션 상품) 안내\n'
#             '위험등급\n'
#             '포트폴리오명\n'
#             '구성상품\n'
#             '투자비중\n'
#             '안정형\n'
#             '(초저위험)\n'
#             '우리은행 디폴트옵션 안정형 포트폴리오\n'
#             '신한은행 디폴트옵션 정기예금 3년\n'
#             '50%\n'
#             '국민은행 디폴트옵션 정기예금 3년\n'
#             '50%\n'
#             '안정\n'
#             '투자형\n'
#             '(저위험)\n'
#             '우리은행 디폴트옵션 안정투자형 \n'
#             '포트폴리오 1\n'
#             '하나은행 디폴트옵션 정기예금 3년\n'
#             '60%\n'
#             '미래에셋전략배분TDF2025혼합자산자투자신탁O\n'
#             '20%\n'
#             '키움키워드림TDF2030증권투자신탁제1호(혼합-재간접형)O\n'
#             '20%\n'
#             '우리은행 디폴트옵션 안정투자형\n'
#             '포트폴리오 2\n'
#             '기업은행 디폴트옵션 정기예금 3년\n'
#             '60%\n'
#             '한화LifeplusTDF2025증권자투자신탁(혼합-재간접형)O\n'
#             '20%',
#  'contexts': ['기본이율×80%×보유일수/계약일수\n'
#               '11개월 이상 ~ 3년 미만\n'
#               '기본이율×90%×보유일수/계약일수\n'
#               '3년 이상\n'
#               '기본이율\n'
#               '  ※ 기본이율 : 신규(또는 재예치)시점 해당 상품의 기본금리\n'
#               '구 분\n'
#               '내 용',
#               '구분\n'
#               '1개월\n'
#               '3개월\n'
#               '6개월\n'
#               '12개월\n'
#               '24개월\n'
#               '36개월\n'
#               '기본금리\n'
#               '연 2.46%\n'
#               '연 2.49%\n'
#               '연 2.45%\n'
#               '연 2.49%\n'
#               '연 2.37%\n'
#               '연 2.49%\n'
#               '※ 현재 적용금리 확인 : 우리은행 인터넷 홈페이지(www.wooribank.com)\n'
#               '구 분\n'
#               '내 용\n'
#               '이자지급시기\n'
#               '• 만기일시지급식(단리식) : 만기(후) 또는 중도해지 요청시 이자를 지급 \n'
#               '만기이자 \n'
#               '산출근거\n'
#               '• 신규금액 × 약정이율 × (계약일수 ÷ 365일)\n'
#               ' ※ 계약일수는 신규일부터 해지일 전일까지 일수를 의미\n'
#               ' [예시] 신규일 2025.01.10.이고 해지일 2025.4.10.인 경우 계약일수 90일\n'
#               '만기후이율\n'
#               '• 만기일 당시 영업점 및 홈페이지에 고시한 일반 정기예금 만기 후 이율 적용\n'
#               '경과기관\n'
#               '이율\n'
#               '1개월이내\n'
#               '만기시점 약정이자율 × 50%',
#               '☞ 금리 등 아래의 내용은 고객의 이해를 돕기 위하여 약정 전에 제공되는 자료로 실제 계약\n'
#               '     내용은 수령하시는 통장 또는 증서에 따릅니다.\n'
#               '구 분\n'
#               '내 용\n'
#               '가입대상\n'
#               '• 실명의 개인\n'
#               '상품유형\n'
#               '• 정기예금\n'
#               '거래방법\n'
#               '• 신규 : 영업점, 인터넷(스마트)뱅킹\n'
#               '• 해지 : 영업점, 인터넷(스마트)뱅킹\n'
#               '가입금액\n'
#               '• 계좌당 1백만원 이상 \n'
#               '계약기간\n'
#               '• 1개월 이상 ~ 36개월 이하 (월 단위, 일 단위 가입 가능) \n'
#               '기본금리\n'
#               '• 신규일(재예치일)에 고시한 계약기간별 이자율 적용 \n'
#               '                                 (금리기준일: 2025.06.20. 세금납부 전 '
#               '기준)\n'
#               ' \n'
#               '구분\n'
#               '1개월 이상\n'
#               '3개월 미만\n'
#               '3개월 이상\n'
#               '6개월 미만\n'
#               '6개월 이상\n'
#               '12개월 미만\n'
#               '12개월 이상\n'
#               '24개월 미만',
#               '250\n'
#               '기타시·군\n'
#               '200\n'
#               '이율\n'
#               '3년제\n'
#               '연 2.2%\n'
#               '3년 초과 \n'
#               '5년제\n'
#               '(최초 3년)\n'
#               '3년 지난 시점의 \n'
#               '3년제 약정이율\n'
#               '(기준일:2025.4.30.\n'
#               '세금공제전)\n'
#               '월저축금\n'
#               ' -월 저축금은 납입 회차별 5만원 이상 50만원 이내에서 원단위로 자유롭게 납입\n'
#               ' -월 입금 횟수에 제한은 없으나, 총 입금 횟수는 해당 계약기간의 월수 초과 불가\n'
#               '가입기간\n'
#               ' 3년 또는 5년 (3년 만기 지난 후 당초계약기간 포함 5년으로 연장 가능)',
#               '- 개인형IRP 신규가입자는 계좌 신규 시 사전지정운용방법을 필수로 선정하여야 함\n'
#               ' 사전지정운용방법(디폴트옵션 상품) 안내\n'
#               '위험등급\n'
#               '포트폴리오명\n'
#               '구성상품\n'
#               '투자비중\n'
#               '안정형\n'
#               '(초저위험)\n'
#               '우리은행 디폴트옵션 안정형 포트폴리오\n'
#               '신한은행 디폴트옵션 정기예금 3년\n'
#               '50%\n'
#               '국민은행 디폴트옵션 정기예금 3년\n'
#               '50%\n'
#               '안정\n'
#               '투자형\n'
#               '(저위험)\n'
#               '우리은행 디폴트옵션 안정투자형 \n'
#               '포트폴리오 1\n'
#               '하나은행 디폴트옵션 정기예금 3년\n'
#               '60%\n'
#               '미래에셋전략배분TDF2025혼합자산자투자신탁O\n'
#               '20%\n'
#               '키움키워드림TDF2030증권투자신탁제1호(혼합-재간접형)O\n'
#               '20%\n'
#               '우리은행 디폴트옵션 안정투자형\n'
#               '포트폴리오 2\n'
#               '기업은행 디폴트옵션 정기예금 3년\n'
#               '60%\n'
#               '한화LifeplusTDF2025증권자투자신탁(혼합-재간접형)O\n'
#               '20%']}

# %% [markdown]
# ## 배치 테스트 & RAGAS 평가
# - 10개 샘플 질의를 선택해 파이프라인을 실행
# - answer relevancy / faithfulness / LLMContextPrecisionWithoutReference으로 지표 계산
# - 레퍼런스가 없기 때문에 LLMContextPrecisionWithoutReference으로 답변과 컨텐스트 정보의 중복 정도로 precision 평가

# %%
# 4. 배치 & RAGAS
from ragas import EvaluationDataset, SingleTurnSample, evaluate
from ragas.metrics import answer_relevancy, faithfulness, LLMContextPrecisionWithoutReference
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# 1) 평가용 LLM/임베딩 (Ragas 래퍼로 감싸기)
evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o-mini", temperature=0))
evaluator_emb = LangchainEmbeddingsWrapper(OpenAIEmbeddings(model="text-embedding-3-small"))

# 2) 그래프 호출 → Ragas 샘플로 변환
SAMPLE_QUESTIONS = [
    # ── 우리 SUPER주거래 적금 ─────────────────────────────
    "우리 SUPER주거래 적금의 3년 만기 기본금리는 얼마인가요?",
    "SUPER주거래 적금에서 우대금리를 받으려면 어떤 거래실적을 충족해야 해?",

    # ── 주택청약예금 ────────────────────────────────────
    "주택청약예금은 누가 가입할 수 있고 최소 가입금액은 얼마인가요?",
    "주택청약예금을 중도해지하면 이율이 어떻게 적용되나요?",

    # ── 우리 자유적금 ───────────────────────────────────
    "우리 자유적금의 최대 월 납입금액이 궁금해요.",
    "우리 자유적금에서 중도해지 시 적용되는 이율은?",

    # ── 정기적금 ────────────────────────────────────────
    "정기적금 3년제 기본금리는 현재 얼마인가요?",
    "정기적금을 만기 지난 뒤 해지하면 어떤 만기후이율이 적용되나요?",

    # ── 첫급여 우리적금 ─────────────────────────────────
    "첫급여 우리적금은 어떤 사람이 가입할 수 있나요?",
    "첫급여 우리적금에서 우대이율을 받기 위한 조건은 무엇인가요?",
]

samples = []
for q in SAMPLE_QUESTIONS:
    res = graph.invoke({"question": q})
    ans = res.get("answer", "")
    ctxs = res.get("contexts", [])
    if isinstance(ctxs, str):
        ctxs = [c for c in ctxs.split("\n\n") if c.strip()]

    samples.append(
        SingleTurnSample(
            user_input=q,
            response=ans,
            retrieved_contexts=ctxs,
        )
    )

dataset = EvaluationDataset(samples=samples)

# 3) 메트릭 설정 (레퍼런스 없이 가능한 조합)
metrics = [
    answer_relevancy,                                       # Q - A 관련성
    faithfulness,                                           # A가 컨텍스트에 근거?
    LLMContextPrecisionWithoutReference(llm=evaluator_llm)  # 컨텍스트가 Q와 관련?
    ]

# 4) 평가 실행
report = evaluate(
    dataset,
    metrics=metrics,
    llm=evaluator_llm,
    embeddings=evaluator_emb,
    show_progress=True,
    batch_size=8,
)

df_scores  = report.to_pandas()

df_overall = df_scores[[
    "answer_relevancy",
    "faithfulness",
    "llm_context_precision_without_reference"
]].mean()

print("=== Overall Metrics ===")
print(df_overall)

print("\n=== Sample-level Metrics (sorted by Faithfulness) ===")
print(df_scores.sort_values("faithfulness")[[
    "user_input",
    "retrieved_contexts",
    'response',
    "answer_relevancy",
    "faithfulness",
    "llm_context_precision_without_reference"
]])
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
# Batch 1/4:   0%|          | 0/8 [00:00<?, ?it/s]
# === Overall Metrics ===
# answer_relevancy                           0.393057
# faithfulness                               0.833333
# llm_context_precision_without_reference    0.736000
# dtype: float64
#
# === Sample-level Metrics (sorted by Faithfulness) ===
#                                   user_input  \
# 0         우리 SUPER주거래 적금의 3년 만기 기본금리는 얼마인가요?
# 2        주택청약예금은 누가 가입할 수 있고 최소 가입금액은 얼마인가요?
# 1  SUPER주거래 적금에서 우대금리를 받으려면 어떤 거래실적을 충족해야 해?
# 3              주택청약예금을 중도해지하면 이율이 어떻게 적용되나요?
# 4                  우리 자유적금의 최대 월 납입금액이 궁금해요.
# 5                 우리 자유적금에서 중도해지 시 적용되는 이율은?
# 6                   정기적금 3년제 기본금리는 현재 얼마인가요?
# 7        정기적금을 만기 지난 뒤 해지하면 어떤 만기후이율이 적용되나요?
# 8                첫급여 우리적금은 어떤 사람이 가입할 수 있나요?
# 9          첫급여 우리적금에서 우대이율을 받기 위한 조건은 무엇인가요?
#
#                                   retrieved_contexts  \
# 0  [및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행...
# 2  [및 특징\n  ￭ 상품명 : 주택청약예금\n  ￭ 상품특징 : 민영주택 또는 민간...
# 1  [및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행...
# 3  [이율\n‣ 중도해지 하는 경우, 별도 중도이율을 적용하지 않고 가입기간\n  별 ...
# 4  [구 분\n내 용\n우대이율\n• 아래 조건 충족하는 경우 최대 연 6.0%p 우대...
# 5  [응할 수 있으며, 이 경우 은행은 별도의 중도해지이율을 적용하지 않으며 중도해지 ...
# 6  [구분\n1개월\n3개월\n6개월\n12개월\n24개월\n36개월\n기본금리\n연 ...
# 7  [만기후이율\n• 만기일 당시 영업점 및 인터넷 홈페이지에 고시한 만기 후 이율 적...
# 8  [및 특징\n⋅상 품 명 : 「우리 첫거래우대 정기예금」\n⋅상품특징 : 50백만원...
# 9  [② 첫급여 이체주2) 시 가입일로부터 1년동안 우대 – 연 1.0%p\n  ※ 가...
#
#                                             response  answer_relevancy  \
# 0        우리 SUPER주거래 적금의 3년 만기 기본금리는 연 2.60%입니다(①4).          0.538513
# 2  주택청약예금은 민영주택 또는 민간건설중형국민주택(분양, 임대)을 공급받고자 하는 자...          0.000000
# 1  「우리 SUPER주거래 적금」에서 우대금리를 받으려면 다음의 부수거래 조건을 충족해...          0.509736
# 3  주택청약예금을 중도해지하는 경우, 별도의 중도이율을 적용하지 않고 가입기간 별 약정...          0.307054
# 4   우리 자유적금의 최대 월 납입금액은 월 최대 1억원 한도 내에서 가입 가능합니다(①).          0.598945
# 5  우리 자유적금에서 중도해지 시 약정한 이율보다 낮은 중도해지이율이 적용됩니다. 또한...          0.218912
# 6                     정기적금 3년제의 기본금리는 연 2.2%입니다(①5).          0.505296
# 7  정기적금을 만기 지난 뒤 해지할 경우, 만기 후 이율이 적용됩니다. 만기 후 이율은...          0.310713
# 8  첫급여 우리적금은 급여이체실적을 충족한 개인 고객이 가입할 수 있습니다. 구체적인 ...          0.522027
# 9  첫급여 우리적금에서 우대이율을 받기 위한 조건은 다음과 같습니다:\n\n1. 고객이...          0.419377
#
#    faithfulness  llm_context_precision_without_reference
# 0      0.000000                                 0.250000
# 2      0.333333                                 1.000000
# 1      1.000000                                 1.000000
# 3      1.000000                                 0.804167
# 4      1.000000                                 0.333333
# 5      1.000000                                 0.679167
# 6      1.000000                                 0.450000
# 7      1.000000                                 1.000000
# 8      1.000000                                 0.926667
# 9      1.000000                                 0.916667

# %%
for i in range(10):
    print('\nuser_input:',df_scores['user_input'][i])
    print('retrieved_contexts:',df_scores['retrieved_contexts'][i])
    print('response:',df_scores['response'][i])
    print('='*120)
# Out:
# user_input: 우리 SUPER주거래 적금의 3년 만기 기본금리는 얼마인가요?
# retrieved_contexts: ['및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품', '기본금리\n• 연 0.1% (세급납부 전 2025.06.10.기준)\n ※ 적용이자율은 매일 변경 고시되며 금리 변경 시에는 변경 고시일부터 변경 적용됩니다.\n우대금리\n• ‘CJ PAY 우리 통장 서비스’ 이용 시, 매일의 최종 잔액 중 2백만원 이하\n  금액에 대해서 아래의 기간 동안 우대금리 및 이벤트 특별금리를 제공합니다.\n• 해지 후 재가입 시 우대금리 및 이벤트 특별금리를 제공하지 않습니다. \n단, 최초 가입일로부터 1개월 이내 재가입한 경우에는 제공합니다.\n구분\n적용요건\n우대기간\n우대금리\n일반 \n우대금리\nCJ PAY 우리 통장 서비스 \n이용시 \n가입일로부터 1년 이내\n연 1.90%p\n가입후 1년 초과 5년 이내\n연 0.40%p\n이벤트 \n특별금리\nCJ PAY 우리 통장 서비스', '달라질 수 있습니다.\n⋅만기 전 해지할 경우 약정한 이율보다 낮은 중도해지이율이 적용됩니다.\n⋅우대금리는 만기 해지 시에만 적용되며, 중도해지하는 경우 적용되지 않습니다.\n⋅’19.7.19.부터 “위비SUPER주거래적금Ⅱ”에서 “우리 SUPER주거래 적금”으로 변경되었습니다.\n  기존에 “위비SUPER주거래적금Ⅱ”를 가입한 고객님께서도 상품명이 “우리 SUPER주거래 적금”  \n  으로 변경되며, 우대이율은 시행일 이후 가입자에 대해서 변경된 상품 내용을 \n  적용받게 됩니다.\n⋅금리변동형 정기적금은 금리상승기에 약정금리 인상 가능성이 큰 반면, 금리 하락기에는 \n   약정금리 인하로 소비자에게 불리할 수 있습니다.', '※ 적용세율은 2024.12.12. 현재의 세율이며, 관계법령의 개정에 따라 변경될 수 있음\n구 분\n내 용\n기본이율\n(세금납부 전\n’24.12.12. 기준)\n• 기본금리는 신규일 당시 영업점 및 인터넷 홈페이지에 고시된 기본금리 적용\n \n계약기간\n기본금리\n6개월 이상 1년 미만\n연 2.20%\n1년 이상 2년 미만\n연 2.60%\n2년 이상 3년 미만\n연 2.60%\n3년 이상 4년 미만\n연 2.60%\n4년 이상 5년 미만\n연 2.65%\n5년\n연 2.65%\n우대이율\n• 아래의 항목에 해당하는 경우 최대 연 0.2%p 적용\n  - 주택청약종합저축 가입고객 연 0.1%p 우대\n  - 급여이체 고객 연 0.1%p\n  - 인터넷 뱅킹으로 상품 가입시 연 0.1%p 우대\n원금 및 \n이자지급제한']
# response: 우리 SUPER주거래 적금의 3년 만기 기본금리는 연 2.60%입니다(①4).
# ========================================================================================================================
#
# user_input: SUPER주거래 적금에서 우대금리를 받으려면 어떤 거래실적을 충족해야 해?
# retrieved_contexts: ['및 특징\n⋅상 품 명 : 「우리 SUPER주거래 적금」\n⋅상품특징 : 우리은행 거래실적에 따라 우대금리를 제공하는 적립식 상품', '일별 잔액\n기본금리\n우대금리\n1,000만원 이하\n\xa0 연 0.1%\n\xa0 최대 연 2.0%p\n1,000만원 초과\n\xa0 미적용\n ※ 기본금리 및 우대금리는 변동될 수 있으며, 금리 변동 시에는 변동일로부터 변\n경된 금리를 적용\n우대금리\n• 아래 우대조건 충족 여부에 따라 우대금리 최대 연 2.0%p 적용\n우대고객\n우대조건\n우대금리\n부수거래\n고객주1)\n\xa0 매월 아래 부수거래 조건 충족 시\n ① 이 예금으로 가맹점 매출대금주2) 입금 시\n ② 우리은행을 통해 가입한 노란우산 정상 계약주3)\n    보유 시\n ③ 우리은행 계좌를 통해 자동이체주4) 3건 이상 납부\n\xa0 부수거래 1개 충족 \n : 연 1.0%p\n\xa0 부수거래 2개 충족 \n : 연 1.5%p\n\xa0 부수거래 3개 충족 \n : 연 2.0%p\n신규/\n비대면\n고객', '달라질 수 있습니다.\n⋅만기 전 해지할 경우 약정한 이율보다 낮은 중도해지이율이 적용됩니다.\n⋅우대금리는 만기 해지 시에만 적용되며, 중도해지하는 경우 적용되지 않습니다.\n⋅’19.7.19.부터 “위비SUPER주거래적금Ⅱ”에서 “우리 SUPER주거래 적금”으로 변경되었습니다.\n  기존에 “위비SUPER주거래적금Ⅱ”를 가입한 고객님께서도 상품명이 “우리 SUPER주거래 적금”  \n  으로 변경되며, 우대이율은 시행일 이후 가입자에 대해서 변경된 상품 내용을 \n  적용받게 됩니다.\n⋅금리변동형 정기적금은 금리상승기에 약정금리 인상 가능성이 큰 반면, 금리 하락기에는 \n   약정금리 인하로 소비자에게 불리할 수 있습니다.']
# response: 「우리 SUPER주거래 적금」에서 우대금리를 받으려면 다음의 부수거래 조건을 충족해야 합니다:
#
# 1. 이 예금으로 가맹점 매출대금 입금 시
# 2. 우리은행을 통해 가입한 노란우산 정상 계약 보유 시
# 3. 우리은행 계좌를 통해 자동이체 3건 이상 납부 시
#
# 부수거래 조건 충족에 따라 우대금리는 다음과 같이 적용됩니다:
# - 부수거래 1개 충족: 연 1.0%p
# - 부수거래 2개 충족: 연 1.5%p
# - 부수거래 3개 충족: 연 2.0%p (①2)
# ========================================================================================================================
#
# user_input: 주택청약예금은 누가 가입할 수 있고 최소 가입금액은 얼마인가요?
# retrieved_contexts: ['및 특징\n  ￭ 상품명 : 주택청약예금\n  ￭ 상품특징 : 민영주택 또는 민간건설중형국민주택(분양,임대)을 공급받고자 하는 자에 대하여 공\n급 우선순위를 부여하기 위한 목적부 정기예금 상품', '□ 청약순위는 주택의 최초 입주자 모집공고일까지 발생되어야 청약이 가능합니다.\n □ 국민주택 청약 시 회차별 입금액이 25만원 이상일 경우, 최대 25만원만 인정되고 그 이상의 금액은 \n    예치금으로 처리됩니다.\n   ※ 회차별 금액 산정 시 입금약정일이 2024년 10월 31일 이전인 경우 최고 10만원, 2024년 11월 1일\n      이후인 경우 최고 25만원 한도로 적용함\n □ 국민주택 청약(일반공급)시 동일 순위 내 경쟁이 있을 경우 납입인정된 회차의 저축총액 또는 \n    납입횟수가 많은 자를 우선으로 입주자 선정하므로, 순위발생일 이후에도 계속해서 납입하는 것이 \n    입주자 선정에 유리할 수 있습니다.', '납부한 금액을 포함하여 주택공급에 관한 규칙에서 정하고 있는 청약예금 최고 예치\n   금액을 초과할 수 없습니다.\n■기타 계약의 주요내용\n  □ 다른 금융기관 또는 제3자 담보제공을 위한 질권설정은 불가합니다.\n  □ 명의변경은 가입자가 사망하여 그 상속인으로 명의를 변경하는 경우에만 가능합니다.\n  □ 당첨된 계좌는 계약체결 여부와 관계없이 청약목적에 재사용할 수 없으며, 추가납입 \n불가합니다. (※단, 분양전환되지 않는 임대주택에 당첨된 경우는 제외)\n  □ 계좌분할(일부지급), 분할해지(일부해지), 양도양수 불가합니다.\n  □ 면적변경 및 지역변경 등 주택청약에 대해 더 궁금한 점이 있으시면 우리은행 인터넷', '및 특징\n⋅상 품 명 : 「WON 적금」\n⋅상품특징 : 스마트폰으로 쉽고 편리하게 가입할 수 있는 적립식 예금 상품', '사전지정운용방법- 포트폴리오 내 상품별 매수/매도 소요기간이 상이\n                    「사전지정운용방법 포트폴리오 상품설명서」 참고\n 모든 상품이 매도 완료되어야 지급* 가능하며, 자세한 사항은 각 상품별 (간이)투자설명서 참고\n  * 지급 : 해지, 계약이전, 중도인출 등\n  ※ 계약이전(현금이전)의 경우 보유 중인 모든 상품이 완료되어야 지급이 가능하며, 계약이전(실물이전)의 경우 \n     실물이전 불가상황 등에 따라 별도의 매도가 발생할 수 있고 매도 소요기간은 각 상품별로 다름\n3\n연금수령/해지/중도인출\n구 분\n내 용\n연금수령\n \n 연금수령 요건 : 55세 이후부터 연금신청 가능\n   - 단, 개인부담금만 있는 경우 55세 이후 & 최초 입금일부터 5년 경과 후 연금신청 가능', '• 회차별 최소 1천원 이상 1천원 단위로, 매월(월 초일부터 말일까지) 70만원 이하\n  ※ 만기일 전일까지 자유롭게 저축 가능, 연간 납입한도 840만원\n구 분\n내 용\n청년희망적금\n만기지급금\n일시납\n• 청년희망적금 만기해지 고객은 청년희망적금 만기지급금 \n  (원금+이자+저축장려금)이내에서 청년도약계좌 가입 시 일시납 가능\n• 최소 200만원 이상 청년희망적금 만기지급금 이하 금액에서 일시납 금액\n  (월 40/50/60/70만원 중 선택), 일시납입 기간 선택 후 일시납 확정\n• 일시납은 청년희망적금 만기일이 속하는 달의 다음 달 말일까지\n  청년도약계좌에 가입신청하는 경우에만 가능\n   ※ (예시) ’24년 2월 만기고객의 경우, ‘24년 3월까지 가입신청 진행필요']
# response: 주택청약예금은 민영주택 또는 민간건설중형국민주택(분양, 임대)을 공급받고자 하는 자에 대해 가입할 수 있습니다. 최소 가입금액에 대한 정보는 해당 내용이 없으므로, 담당 직원 확인 후 안내드리겠습니다.
# ========================================================================================================================
#
# user_input: 주택청약예금을 중도해지하면 이율이 어떻게 적용되나요?
# retrieved_contexts: ['이율\n‣ 중도해지 하는 경우, 별도 중도이율을 적용하지 않고 가입기간\n  별 약정이율을 적용 \n이자계산방법\n‣ 입금건별로 해당 기간에 대해 약정이율로 계산한 후 총 합계 금액\n  을 해지 시 지급   \n   ※ 가입기간 1년, 3회차 납부 후 해지 예시                                         \n     \n예금만기\n‣ 영업점 방문을 통한 해지 가능', '및 특징\n  ￭ 상품명 : 주택청약예금\n  ￭ 상품특징 : 민영주택 또는 민간건설중형국민주택(분양,임대)을 공급받고자 하는 자에 대하여 공\n급 우선순위를 부여하기 위한 목적부 정기예금 상품', '및 \n조기상환권\n ￭ 예금 가입 이후 본 예금의 중도해지는 원칙적으로 허용되지 않습니다.\n 단, 고객의 부득이한 사정에 의해 예금 전액에 대하여 중도해지를 요청하는\n 경우 은행은 이에 응할 수 있으며, 이 경우 은행은 별도의 중도해지이율을 \n 적용하지 않으며  중도해지수수료를 원금에 더하거나 또는 제외하고\n 고객이 지정한 계좌로 입금합니다.', '• 신규일 또는 자동 재예치일주1) 현재 영업점 및 인터넷 홈페이지에\n 게시된 기간별 차등 이율이 적용됨\n  주1) 해당일이 은행영업일이 아닌 경우 직전 영업일의 이율이 적용되며, \n  해당일이 없는 경우 그 달의 말일의 이율이 적용됨\n※ 실제적용금리는 우리은행 영업점 및 홈페이지(www.wooribank.com) 에서 확인 가능\n계약기간\n3개월\n6개월\n1년\n2년\n3년\n이자율\n연1.98%\n연2.15%\n연2.39%\n연2.07%\n연2.21%\n이자계산방법\n• 예금가입금액 × 계약기간별 연 이율 × 일수 / 365 \n이자지급방법\n• 만기일시지급식 : 만기 또는 중도해지 요청시 이자를 지급\n원금 또는 이자\n지급관련 제한\n• 계좌에 압류, 가압류, 질권설정 등이 등록될 경우 원금 및 이자 지급 제한', '1인당 “5천만원까지”(본 은행의 여타 보호상품과 합산) 보호됩니다.\n특별 중도해지\n가입 후 (또는 재예치일) 1개월이 지나고 다음 각 호의 사유에 해당되는 \n경우, 약정이율 적용\n① 당첨 후 해지시\n② 예치금액 변경(면적변경, 지역변경)으로 인한 해지 시\n③ 사망에 의한 상속으로 1인 2계좌 이상이 되어 해지 시\n세제혜택\n본인의 가입한도 내에서 비과세로 가입 가능\n    3\n 유의 사항\n       ￭ 만기전 해지할 경우 약정한 이율보다 낮은 중도해지 이율이 적용됩니다.\n    \n 상품가입 후 의문사항 또는 불만(민원)이 있을 경우 우리은행 고객센터(☎1588-5000 평일 09:00~18:00)', '▷ 어린이 전용 적금상품으로 자유롭게 적립 가능한 적금\n기본금리\n(세금납부 전)\n’25.06.20. 기준\n ▷ 아래의 이율은 2025.06.20. 세금납부 전 기준 이율이며 신규 당시의 \n    이율은 실제로 통장에 인자된 이율이 적용됩니다.\n    (인터넷 가입 시는 가입화면에서 확인)\n    \n계약기간\n기본금리(%)\n최고금리(%)\n12개월\n 연 2.45%\n연 3.65%\n우대이율\n(세금납부전)\n ▷ 적금 계약기간 중 지문등록 후 [아동등 사전신고증]을 계약기간의 \n    만기일 전일까지 제출하는 경우 : 연 1.0%p\n   ※ 지문등록 대상과 가입자 일치 필요\n    ※ [아동 등 사전신고증]은 경찰서 방문 또는 안전Dream 홈페이지에서 발급 가능']
# response: 주택청약예금을 중도해지하는 경우, 별도의 중도이율을 적용하지 않고 가입기간 별 약정이율이 적용됩니다(①1).
# ========================================================================================================================
#
# user_input: 우리 자유적금의 최대 월 납입금액이 궁금해요.
# retrieved_contexts: ['구 분\n내 용\n우대이율\n• 아래 조건 충족하는 경우 최대 연 6.0%p 우대금리 제공 \n① 직전반기말일 기준 우리은행 계좌 미보유 고객 : 연 3.00%p\n② 직전 6개월 동안 우리은행 예·적금 미보유 고객 : 연 3.00%p\n  단, 14세 이상인 경우 우리은행 상품·서비스 마케팅 동의 항목 중 전화(휴대폰)나 SMS 중 \n하나 이상 동의 후 만기해지시점까지 유지한 경우 제공하며 마케팅 동의가 불가능한 14세 \n미만은 마케팅 동의여부를 확인하지 않고 조건 충족시 우대금리 제공합니다. \n• 우대이율은 계약기간 만기 전 중도해지한 계좌에 대해서는 적용하지 않음  \n만기앞당김\n• 불가\n이자지급시기\n• 만기일시지급식 : 만기(후) 또는 중도해지 요청시 이자를 지급 \n적용세율', '금융소비자에게 수수료, 위약금 등 비용을 요구할 수 없습니다. \n     *  부적합한 금융상품을 권유한 경우(제17조 제3항), 적정하지 않은 금융상품에 대해\n      부적정하다는 사실을 알리지 않은 경우(제18조 제2항), 금융상품에 대해 거짓 또는\n      왜곡하여 설명하거나 중요한 사항에 대한 설명을 누락한 경우(제19조 제1항, 제3항),\n      불공정영업행위의 금지(제20조 제1항), 부당권유행위의 금지(제21조) \n매일 자동적립\n서비스\n• N일 적금(31일) 신규 시 지정한 금액을 신규일 익일부터 만기 직전일까지 \n매일 사전에 지정한 본인 명의의 우리은행 출금계좌에서 이 적금으로 \n이체하는 자동이체 서비스이며 일반 자동이체 서비스와 중복하여 등록불가\n매일 알림 \n서비스', '가입금액\n• 제한없음\n적립한도\n• 월 최대 1억원 한도 내에서 가입 가능\n계약기간\n• 6개월 이상 5년 이하 월 단위 또는 일 단위\n적용금리\n• 적용금리 : 기본이율 + 우대이율\n기본이율\n(세금납부 전\n’24.12.12. 기준)\n• 아래의 이율은 2024.12.12. 기준 이율이며 신규 당시의 이율은 실제로 \n  통장에 인자된 이율이 적용됩니다. (인터넷 가입 시는 가입화면에서 확인)\n  \n계약기간\n기본금리\n6개월 이상 1년 미만\n연 2.05%\n1년 이상 2년 미만\n연 2.25%\n2년 이상 3년 미만\n연 2.25%\n3년 이상\n연 2.30%\n구 분\n내 용\n우대이율\n• 아래의 항목에 해당하는 경우 최대 연 0.3%p 적용\n  - 주택청약종합저축 가입고객 또는 인터넷뱅킹(스마트뱅킹)으로 상품 가입시', '우대이자율\n• 신규일 당시 영업점 및 인터넷 홈페이지에 고시한 조건별 우대이율 적용\n• 적용조건 : 아래 우대조건 충족여부에 따라 최대 연 0.2%p 우대이율 적용\n  ① 이 적금을 「우리꿈통장, WON 통장」에 연결하여 가입하는 경우\n     - 연 0.1%p\n  ② 만기해지 시 우리 오픈뱅킹 서비스주1)에 타행계좌가 등록되어 있는 경우\n     - 연 0.1%p\n• 우대이율은 계약기간 만기 전 중도해지한 계좌에 대해서는 적용하지 않음\n주1) 우리 오픈뱅킹 서비스 : 오픈뱅킹 공동업무를 활용하여 우리은행이 이용자에게 제공하는\n     금융거래 서비스\n만기후이자율\n• 만기일 당시 영업점 및 인터넷 홈페이지에 고시한 경과기간별 만기 후 \n이자율 적용\n  \n경과기간\n이율\n만기후 1개월이내', '1. 투자자 유형에 따른 모델포트폴리오 : 총 11종의 모델포트폴리오 운용\n  - 매우낮은위험 : 1종, 낮은위험 : 3종, 보통위험 : 3종, 다소높은위험 : 2종, 높은위험 : 2종\n투자자유형\n모델포트폴리오명\n서비스유형\n운용방식\n높은위험\n 우리 일임형 글로벌우량주 ISA(공격형)\n펀드운용형\n본사운용형\n 우리 일임형 국내우량주 ISA(공격형)\n펀드운용형\n본사운용형\n다소높은위험\n 우리 일임형 글로벌인컴 ISA(적극투자형)\n펀드운용형\n본사운용형\n 우리 일임형 글로벌50 ISA(적극투자형)\n펀드운용형\n본사운용형\n보통위험\n 우리 일임형 고배당30 ISA(위험중립형)\n펀드운용형\n본사운용형\n 우리 일임형 글로벌30 ISA(위험중립형)\n펀드운용형\n본사운용형\n 우리 일임형 공모주알파 ISA(위험중립형)\n펀드운용형']
# response: 우리 자유적금의 최대 월 납입금액은 월 최대 1억원 한도 내에서 가입 가능합니다(①).
# ========================================================================================================================
#
# user_input: 우리 자유적금에서 중도해지 시 적용되는 이율은?
# retrieved_contexts: ['응할 수 있으며, 이 경우 은행은 별도의 중도해지이율을 적용하지 않으며 중도해지 수수료를 \n지급금액에 더하거나 또는 제외하고 고객이 지정한 계좌로 입금합니다.', '제1항, 제3항에 따라 금융상품에 관한 중요한 사항을 이해하기 쉽도록 설명하기 위해 \n  설명을 하기 전에 제공되는 자료로서, 상담일 이후 가입금액, 계약기간 등 변경에 의하여 일부 \n내용이 달라질 수 있습니다.\n⋅만기 전 해지할 경우 약정한 이율보다 낮은 중도해지이율이 적용됩니다.\n⋅우대이율은 만기해지 시에만 적용되며, 중도해지 하는 경우 적용되지 않습니다.\n⋅우리카드 대중교통 후불결제 우대금리는 적금 만기해지 시점까지 우리카드를 보유하고 결제계좌를 \n우리은행 입출금통장으로 지정해야만 적용됩니다.\n⋅금리변동형 정기적금은 금리상승기에 약정금리 인상 가능성이 큰 반면, 금리 하락기에는\n약정금리 인하로 소비자에게 불리할 수 있습니다.', '중도\n해지이자율\n • 신규일 당시 영업점 및 홈페이지에 고시한 중도해지이율 적용\n • 입금금액마다 입금일부터 중도해지일 전일까지의 기간에 대하여 예치기간별', '수수료는 고객의 중도해지 요청에 따라 은행에게 발생한 비용이나 손실(예금과 \n관련하여 은행이 취한 헷징 포지션을 해소하는 데에 필요한 비용을 포함함) 또는 은행에게 \n발생한 수익이나 이익으로 해지 시점의 시장가격에 따라 은행이 계산대리인으로서 공정하게 \n산정합니다.\n   ￭ 중도해지 시 예상 중도해지수수료 산출 조견표\n      - 본 조견표는 고객이 만기일 이전에 중도해지를 신청하는 경우 적용되는 중도해지수수료를 사전적으로 \n명시하기 어려운 복합예금상품의 특성상 고객의 이해를 돕기 위해 작성된 것입니다.\n     현재 시점의 금융시장 변수 중 다른 조건은 동일하게 유지됨을 가정하고 기준금리 및 이자율 스왑금리가', '0%\n 0.07%~0.15%\n 0.02%~0.03% \n0.01%~0.03%\n0.30%~0.41%\n매우 \n낮은 \n위험\n우리 일임형 안정형 ISA(안정형)\n연 0.1%\n(분기당 후취)\n 0% \n 0.07%~0.10% \n0.01%~0.03%\n0.01%~0.01%\n0.19%~0.24%\n  - 일임운용보수는 매분기 첫 영업일 또는 계약해지시에 기간별 평균 \n    평가금액 기준으로 징수. 단 전분기말 기준 또는 만기해지시, 일임운용보수를 \n    차감한 계좌별 평가금액이 원금 미만일 경우 면제함. \n  - 계약종료일 이후 계약해지를 위한 투자자의 별도 행위가 없는 경우, 그 이후에 적용되는 일임 보수율은 기 적용 보수율의 1/2로 적용\n  - 편입된 개별 펀드 등의 보수는 모델포트폴리오 일임운용수수료와', '• 이 예금은 CJ올리브네트웍스 주식회사의 앱 또는 웹 페이지에 연계된\n  「우리은행 비대면 실명확인 서비스」를 통해서만 가입이 가능하며,\n  [CJ올리브네트웍스 제휴서비스 / CJ PAY 우리 통장 서비스](이하 ‘CJ PAY\n  우리 통장 서비스’라 한다.) 이용* 시 연계ㆍ제휴 서비스를 제공합니다.\n   * CJ PAY 우리 통장을 CJ PAY에 연결하여 결제 등의 서비스 이용 시\n상품명\n• ‘CJ PAY 우리 통장 서비스’ 해지 시 「우리 제휴 통장」으로 상품명 변경\n이자계산 및 \n이자지급방법\n• 예금의 이자 결산은 매월 셋째 금요일에 실시하며, 결산일이 공휴일인 \n  경우 그 직전 영업일에 계산하여 그 익일(원가일)에 원금에 더함']
# response: 우리 자유적금에서 중도해지 시 약정한 이율보다 낮은 중도해지이율이 적용됩니다. 또한, 중도해지 시 우대이율은 적용되지 않습니다(①2). 중도해지이율은 신규일 당시 영업점 및 홈페이지에 고시한 중도해지이율이 적용됩니다(①3).
# ========================================================================================================================
#
# user_input: 정기적금 3년제 기본금리는 현재 얼마인가요?
# retrieved_contexts: ['구분\n1개월\n3개월\n6개월\n12개월\n24개월\n36개월\n기본금리\n연 2.46%\n연 2.49%\n연 2.45%\n연 2.49%\n연 2.37%\n연 2.49%\n※ 현재 적용금리 확인 : 우리은행 인터넷 홈페이지(www.wooribank.com)\n구 분\n내 용\n이자지급시기\n• 만기일시지급식(단리식) : 만기(후) 또는 중도해지 요청시 이자를 지급 \n만기이자 \n산출근거\n• 신규금액 × 약정이율 × (계약일수 ÷ 365일)\n ※ 계약일수는 신규일부터 해지일 전일까지 일수를 의미\n [예시] 신규일 2025.01.10.이고 해지일 2025.4.10.인 경우 계약일수 90일\n만기후이율\n• 만기일 당시 영업점 및 홈페이지에 고시한 일반 정기예금 만기 후 이율 적용\n경과기관\n이율\n1개월이내\n만기시점 약정이자율 × 50%', '기본금리\n• 연 0.1% (세급납부 전 2025.06.10.기준)\n ※ 적용이자율은 매일 변경 고시되며 금리 변경 시에는 변경 고시일부터 변경 적용됩니다.\n우대금리\n• ‘CJ PAY 우리 통장 서비스’ 이용 시, 매일의 최종 잔액 중 2백만원 이하\n  금액에 대해서 아래의 기간 동안 우대금리 및 이벤트 특별금리를 제공합니다.\n• 해지 후 재가입 시 우대금리 및 이벤트 특별금리를 제공하지 않습니다. \n단, 최초 가입일로부터 1개월 이내 재가입한 경우에는 제공합니다.\n구분\n적용요건\n우대기간\n우대금리\n일반 \n우대금리\nCJ PAY 우리 통장 서비스 \n이용시 \n가입일로부터 1년 이내\n연 1.90%p\n가입후 1년 초과 5년 이내\n연 0.40%p\n이벤트 \n특별금리\nCJ PAY 우리 통장 서비스', '기본이율×80%×보유일수/계약일수\n11개월 이상 ~ 3년 미만\n기본이율×90%×보유일수/계약일수\n3년 이상\n기본이율\n  ※ 기본이율 : 신규(또는 재예치)시점 해당 상품의 기본금리\n구 분\n내 용', '☞ 금리 등 아래의 내용은 고객의 이해를 돕기 위하여 약정 전에 제공되는 자료로, 실제 계약\n     내용은 수령하시는 통장이나 증서 또는 비대면 채널의 계좌 상세조회에 따릅니다.\n구 분\n내 용\n가입대상\n• 사업자 등록증을 소지한 실명의 개인사업자 및 법인(1인 1계좌)\n  (금융회사 등 및 기관투자가 제외)\n상품유형\n• 정기적금 (정액적립식)\n거래방법\n• 신규 : 인터넷뱅킹, 스마트뱅킹\n• 해지 : 영업점, 인터넷뱅킹, 스마트뱅킹 \n가입금액\n• 월 100만원 이하로 지정한 금액\n계약기간\n• 12개월 \n적용이율\n(세금납부 전 \n’25.07.01. 기준)\n• 적용금리 : 기본금리 + 우대금리\n• 기본금리는 신규일 당시 영업점 및 홈페이지에 고시된 기본금리 적용 \n \n계약기간\n기본금리\n최고금리\n비고\n12개월', '250\n기타시·군\n200\n이율\n3년제\n연 2.2%\n3년 초과 \n5년제\n(최초 3년)\n3년 지난 시점의 \n3년제 약정이율\n(기준일:2025.4.30.\n세금공제전)\n월저축금\n -월 저축금은 납입 회차별 5만원 이상 50만원 이내에서 원단위로 자유롭게 납입\n -월 입금 횟수에 제한은 없으나, 총 입금 횟수는 해당 계약기간의 월수 초과 불가\n가입기간\n 3년 또는 5년 (3년 만기 지난 후 당초계약기간 포함 5년으로 연장 가능)', '및 특징\n⋅상 품 명 : 「원비즈플라자 멤버십 적금」\n⋅상품특징 : 원비즈플라자 회원사를 위한 특판 정기적금\n ※ 원비즈플라자란? 입찰 요청부터 계약, 발주 관리까지 모든 구매 및 발주에 필요한 기능과 금융지원까지 \n                    한꺼번에 제공하는 공금망 금융 플랫폼']
# response: 정기적금 3년제의 기본금리는 연 2.2%입니다(①5).
# ========================================================================================================================
#
# user_input: 정기적금을 만기 지난 뒤 해지하면 어떤 만기후이율이 적용되나요?
# retrieved_contexts: ['만기후이율\n• 만기일 당시 영업점 및 인터넷 홈페이지에 고시한 만기 후 이율 적용\n  \n경과기간\n이율\n만기후 1개월이내\n만기시점 약정이율 × 50%\n만기후 1개월 초과 ~ 6개월 이내\n만기시점 약정이율 × 30%\n만기후 6개월 초과\n만기시점 약정이율 × 20%\n   ※ 약정이율 : 만기(또는 재예치)시점 일반정기적금 기본금리\n만기이자 \n산출근거\n• 입금 건별로 입금일부터 지급 전일까지의 기간에 대하여 약정이율로 \n  계산한 후 총 합계 금액을 지급\n  [입금건별 이자계산 산식] 입금금액 × 약정이율 × 일수(입금일~만기일 전일)/365', '만기 후 이율\n• 만기일 당시 영업점 및 인터넷 홈페이지에 고시한만기 후 이율 적용\n  \n경과기간\n이율\n만기후 1개월이내\n만기시점 약정이율 × 50%\n만기후 1개월 초과 ~ 6개월 이내\n만기시점 약정이율 × 30%\n만기후 6개월 초과\n만기시점 약정이율 × 20%\n   ※ 약정이율 : 만기(또는 재예치)시점 일반정기적금 기본금리\n만기이자 \n산출근거\n• 입금 건별로 입금일부터 지급 전일까지의 기간에 대하여 약정이율로 \n  계산한 후 총 합계 금액을 지급\n  [입금건별 이자계산 산식] 입금금액 × 약정이율 × 일수(입금일~만기일 전일)/365', '250\n기타시·군\n200\n이율\n3년제\n연 2.2%\n3년 초과 \n5년제\n(최초 3년)\n3년 지난 시점의 \n3년제 약정이율\n(기준일:2025.4.30.\n세금공제전)\n월저축금\n -월 저축금은 납입 회차별 5만원 이상 50만원 이내에서 원단위로 자유롭게 납입\n -월 입금 횟수에 제한은 없으나, 총 입금 횟수는 해당 계약기간의 월수 초과 불가\n가입기간\n 3년 또는 5년 (3년 만기 지난 후 당초계약기간 포함 5년으로 연장 가능)', '이율\n(기준일: \n2025.4.30. \n세금공제 전)\n1개월 이상\n~1년 미만\n연 1%\n1년 이상\n~2년 미만\n연 2%\n2년 이상\n~3년 미만\n연 2%\n3년 이상~\n약정이율\n만기 후 이율\n -미당첨 계좌 : 약정이율\n -당첨계좌(만기 후 1년 이내) : 약정이율 x 1/2 (연동적용)\n -당첨계좌(만기 후 1년 초과) : 연 1% \n이자 지급방식\n변경\n -이자 계산방법 : 단리식\n -납입금 완납 여부와 관계없이 만기 지난 계좌에 한해 청구일 전일까지 이자지급\n -최종 이자지급일로부터 1년 지날 때마다 이자지급 가능\n계약의 해지\n 영업점에서 해지 가능\n예금자보호여부\n해당\n이 예금은 예금자보호법에 따라 원금과 소정의 이자를 합하여 \n1인당 “5천만원까지”(본 은행의 여타 보호상품과 합산) 보호됩니다.', '네이버 스마트스토어 매출대금, 네이버페이 가맹점 정산대금\n     (단, 우리은행에서 정하지 않은 일부 온라인 결제대금 또는 가맹본부로부터 정산받은 매출대금은\n     “가맹점 매출대금”으로 인정하지 않음)\n주3) 노란우산 계약 해지, 월부금 연체 시 해당되지 않음\n주4) 아파트관리비, 지로/펌뱅킹/CMS 자동납부 시 해당되며, 계좌간 자동이체는 해당되지 않음\n주5) 거래중지계좌를 보유한 경우에는 해당되지 않음\n ※ 예금 해지 시 우대금리는 예금 해지일이 1~9일인 경우 전전월말 기준, 10일~\n말일인 경우 전월말 기준 우대조건 충족 여부를 확인하여 지난 원가일로부터 \n예금 해지일 전일까지 적용']
# response: 정기적금을 만기 지난 뒤 해지할 경우, 만기 후 이율이 적용됩니다. 만기 후 이율은 경과 기간에 따라 다르게 적용되며, 만기일 당시 영업점 및 인터넷 홈페이지에 고시한 만기 후 이율이 기준이 됩니다. 구체적으로는 다음과 같습니다:
#
# - 만기 후 1개월 이내: 만기 시점 약정이율 × 50%
# - 만기 후 1개월 초과 ~ 6개월 이내: 만기 시점 약정이율 × 30%
# - 만기 후 6개월 초과: 만기 시점 약정이율 × 20%입니다(①1, ②2).
# ========================================================================================================================
#
# user_input: 첫급여 우리적금은 어떤 사람이 가입할 수 있나요?
# retrieved_contexts: ['및 특징\n⋅상 품 명 : 「우리 첫거래우대 정기예금」\n⋅상품특징 : 50백만원 한도로 가입 가능한 개인고객 대상 정기예금', '② 첫급여 이체주2) 시 가입일로부터 1년동안 우대 – 연 1.0%p\n  ※ 가입후 2개월간(급여이체 변경후 실적체크 불가 기간)은 우대금리 기본제공\n※ 위 금리는 조회기준일 현재 우대금리로서 변동될 수 있으며, 금리 변동 시 변동일로부터 변경된 금리를 적용\n 주1) 급여이체 실적 : 아래 중 하나 이상 충족한 경우 \n  1. 고객이 지정한 이체일 기준으로 이 통장에 100만원 이상 입금한 경우\n    (지정한 이체일에 입금되어야 인정되며 지정한 이체일이 휴일인 경우\n     전/후 영업일에 입금된 경우도 포함하여 이체 여부를 확인)     \n  2. 이 통장 적요란의 문구에 “급여”, “월급”, “급료”, “수당”이 인쇄된 이체실적이 월 100만원 \n이상인 경우', '및 특징\n⋅상 품 명 : 「첫급여 우리적금」\n⋅상품특징 : 급여이체실적 충족월수에 따라 차등 우대금리를 제공하는 적립식 상품', '및 특징\n⋅상 품 명 : 「WON 적금」\n⋅상품특징 : 스마트폰으로 쉽고 편리하게 가입할 수 있는 적립식 예금 상품', '• 정상일반세율은 이자소득의 15.4% (이자소득세(14.0%)+지방소득세(1.4%))\n ※ 적용세율은 2025.03.28. 현재의 세율이며, 관계법령의 개정에 따라 변경될 수 있음\n구 분\n내 용\n우대금리\n(2025.03.28./\n세금납부 전 \n기준)      \n   \n• 우대금리 (2025.03.28. 기준)\n  전월 아래 우대조건 충족시 전월 결산일부터 이번 달 결산일 \n  전일까지 기간동안 매일 최종 잔액 중 2백만원 이하의 금액에 대해 영업점 및 \n  홈페이지에 고시된 우대금리를 기본금리에 더하여 적용(최대 연 3.0%p)\n  ① 전월 급여이체주1) 실적 보유 시 – 연 2.0%p\n  ② 첫급여 이체주2) 시 가입일로부터 1년동안 우대 – 연 1.0%p', '의하여 일부 내용이 달라질 수 있습니다.\n⋅만기 전 해지할 경우 약정한 이율보다 낮은 중도해지이율이 적용됩니다.\n⋅「조세특례제한법」 제91조의21에 따라 청년희망적금에 가입한 사람은 이 적금에 가입할 수 \n  없습니다. (단, 청년희망적금 해지 후 이 적금에 가입 가능합니다)\n⋅외국인의 경우 실명확인증표는 외국인등록증(영주증) 및 국내거소신고증에 한합니다.\n⋅원활한 정부기여금 운영을 위해 입금한 금액의 입금거래 정정(취소·변경 등)은 제한될 수 \n  있습니다.\n⋅우대금리는 만기해지 시에만 적용되며, 중도해지하는 경우 적용되지 않습니다.\n⋅금리변동형 정기적금은 금리상승기에 약정금리 인상 가능성이 큰 반면, 금리 하락기에는 \n  약정금리 인하로 소비자에게 불리할 수 있습니다.']
# response: 첫급여 우리적금은 급여이체실적을 충족한 개인 고객이 가입할 수 있습니다. 구체적인 가입 조건은 급여이체 실적에 따라 차등 우대금리를 제공하는 적립식 상품입니다(①3).
# ========================================================================================================================
#
# user_input: 첫급여 우리적금에서 우대이율을 받기 위한 조건은 무엇인가요?
# retrieved_contexts: ['② 첫급여 이체주2) 시 가입일로부터 1년동안 우대 – 연 1.0%p\n  ※ 가입후 2개월간(급여이체 변경후 실적체크 불가 기간)은 우대금리 기본제공\n※ 위 금리는 조회기준일 현재 우대금리로서 변동될 수 있으며, 금리 변동 시 변동일로부터 변경된 금리를 적용\n 주1) 급여이체 실적 : 아래 중 하나 이상 충족한 경우 \n  1. 고객이 지정한 이체일 기준으로 이 통장에 100만원 이상 입금한 경우\n    (지정한 이체일에 입금되어야 인정되며 지정한 이체일이 휴일인 경우\n     전/후 영업일에 입금된 경우도 포함하여 이체 여부를 확인)     \n  2. 이 통장 적요란의 문구에 “급여”, “월급”, “급료”, “수당”이 인쇄된 이체실적이 월 100만원 \n이상인 경우', '단, 우대이율은 만기해지 시점까지 우리은행 상품·서비스 마케팅 동의\n  항목 중 전화(휴대폰) 및 SMS 항목을 모두 동의한 경우 제공\n우대조건\n비 고\n1. 가입시점에 우리은행 정기예금 및 적금 상품을 보유하지 \n   않은 경우\n연 1.00%p\n2. 가입기간의 1/2 이상 납입하고, 상품 전용 관리페이지에서 \n   감정스탬프를 가입기간의 3/4 이상 선택한 경우\n연 2.00%p\n• 우대이율은 계약기간 만기 전 중도해지한 계좌에 대해서는 적용하지 않음\n우대이율\n적용 예시\n• 이율 계산 방법 : 매일 입금된 금액마다 입금일로부터 만기해지일 \n전일까지의 기간에 대하여 기본이율에 우대이율을 더하여 계산한\n  이자를 원금에 더하여 만기일에 일시 지급\n  ① 마케팅 동의를 유지한 경우 \n    \n구 분\n사례 1', '및 특징\n⋅상 품 명 : 「우리WON모바일 적금」\n⋅상품특징 : MVNO 가입고객 누구나 우대이율을 받을 수 있고, 통신비 자동이체 고객에게 \n            추가혜택을 제공하는 적금', '이체하는 자동이체 서비스이며 일반 자동이체 서비스와 중복하여 등록불가\n매일 알림 \n서비스\n• 고객이 우대이율을 받을 수 있도록 신청 고객에게 매일 우리 WON뱅킹 \n앱으로 PUSH를 보내, 적금의 납입 및 상품 전용 관리페이지의 감정스탬프 \n선택을 안내하는 서비스\n구 분\n내 용\n만기자동해지\n서비스\n• 신규일에 고객이 신청한 우리은행 입출금계좌로\n  만기해지 원리금이 자동 입금되는 서비스\n• 고객이 신청하는 경우에 한하여 적용되며, 가입 이후에도 신청 및 변경 가능\n자료열람\n요구권\n• 금융소비자는 분쟁조정 또는 소송의 수행 등 권리구제를 위한 목적으로\n  은행이 기록 및 유지·관리하는 다음의 자료에 대한 열람(사본 및 청취 \n  포함)을 요구할 수 있습니다.']
# response: 첫급여 우리적금에서 우대이율을 받기 위한 조건은 다음과 같습니다:
#
# 1. 고객이 지정한 이체일 기준으로 이 통장에 100만원 이상 입금해야 합니다. 지정한 이체일이 휴일인 경우 전/후 영업일에 입금된 경우도 포함됩니다(①1).
# 2. 이 통장 적요란의 문구에 “급여”, “월급”, “급료”, “수당”이 인쇄된 이체실적이 월 100만원 이상이어야 합니다(①1).
# 3. 우대이율은 만기해지 시점까지 우리은행 상품·서비스 마케팅 동의 항목 중 전화(휴대폰) 및 SMS 항목을 모두 동의한 경우에 제공됩니다(①2).
#
# 이 외에도 가입 시점에 우리은행 정기예금 및 적금 상품을 보유하지 않은 경우 연 1.00%p의 우대이율이 제공됩니다(①2).
# ========================================================================================================================

# %% [markdown]
# - answer_relevancy ≥ 0.8 이면 FAQ 일치율 양호   낮으면 프롬프트/쿼리 확장/리트리버 k값 조정.
#
# - faithfulness < 0.9 라면 Prompt 수정·retriever k값 조정 필요, ‘컨텍스트 내 근거 인용’ 지시 강화, 답변 길이 제한, 시스템 프롬프트 보강.
#
# - context_precision 은 1.0에 가까울수록 불필요한 문맥이 적음. 임베딩 모델/토크나이저, 인덱스 파라미터(HNSW, k), 쿼리 재작성 확인.
#
#  OOD(미지원 질문)용 거절 정확도 같은 보조 지표도 추가하면 좋을 듯.
